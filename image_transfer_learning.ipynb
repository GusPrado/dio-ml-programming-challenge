# %% [markdown]
# <a href="https://colab.research.google.com/github/GusPrado/dio-ml-programming-challenge/blob/main/image_transfer_learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Transfer learning / fine-tuning
#
# This tutorial will guide you through the process of using _transfer learning_ to learn an accurate image classifier from a relatively small number of training samples. Generally speaking, transfer learning refers to the process of leveraging the knowledge learned in one model for the training of another model.
#
# More specifically, the process involves taking an existing neural network which was previously trained to good performance on a larger dataset, and using it as the basis for a new model which leverages that previous network's accuracy for a new task. This method has become popular in recent years to improve the performance of a neural net trained on a small dataset; the intuition is that the new dataset may be too small to train to good performance by itself, but we know that most neural nets trained to learn image features often learn similar features anyway, especially at early layers where they are more generic (edge detectors, blobs, and so on).
#
# Transfer learning has been largely enabled by the open-sourcing of state-of-the-art models; for the top performing models in image classification tasks (like from [ILSVRC](http://www.image-net.org/challenges/LSVRC/)), it is common practice now to not only publish the architecture, but to release the trained weights of the model as well. This lets amateurs use these top image classifiers to boost the performance of their own task-specific models.
#
# #### Feature extraction vs. fine-tuning
#
# At one extreme, transfer learning can involve taking the pre-trained network and freezing the weights, and using one of its hidden layers (usually the last one) as a feature extractor, using those features as the input to a smaller neural net.
#
# At the other extreme, we start with the pre-trained network, but we allow some of the weights (usually the last layer or last few layers) to be modified. Another name for this procedure is called "fine-tuning" because we are slightly adjusting the pre-trained net's weights to the new task. We usually train such a network with a lower learning rate, since we expect the features are already relatively good and do not need to be changed too much.
#
# Sometimes, we do something in-between: Freeze just the early/generic layers, but fine-tune the later layers. Which strategy is best depends on the size of your dataset, the number of classes, and how much it resembles the dataset the previous model was trained on (and thus, whether it can benefit from the same learned feature extractors). A more detailed discussion of how to strategize can be found in [[1]](http://cs231n.github.io/transfer-learning/) [[2]](http://sebastianruder.com/transfer-learning/).
#
# ## Procedure
#
# In this guide will go through the process of loading a state-of-the-art, 1000-class image classifier, [VGG16](https://arxiv.org/pdf/1409.1556.pdf) which [won the ImageNet challenge in 2014](http://www.robots.ox.ac.uk/~vgg/research/very_deep/), and using it as a fixed feature extractor to train a smaller custom classifier on our own images, although with very few code changes, you can try fine-tuning as well.
#
# We will first load VGG16 and remove its final layer, the 1000-class softmax classification layer specific to ImageNet, and replace it with a new classification layer for the classes we are training over. We will then freeze all the weights in the network except the new ones connecting to the new classification layer, and then train the new classification layer over our new dataset.
#
# We will also compare this method to training a small neural network from scratch on the new dataset, and as we shall see, it will dramatically improve our accuracy. We will do that part first.
#
# As our test subject, we'll use a dataset consisting of around 6000 images belonging to 97 classes, and train an image classifier with around 80% accuracy on it. It's worth noting that this strategy scales well to image sets where you may have even just a couple hundred or less images. Its performance will be lesser from a small number of samples (depending on classes) as usual, but still impressive considering the usual constraints.

# %%
# %matplotlib inline

import os

#if using Theano with GPU
#os.environ["KERAS_BACKEND"] = "tensorflow"

import random
import numpy as np
import keras

import matplotlib.pyplot as plt
from matplotlib.pyplot import imshow

from keras.preprocessing import image
from keras.applications.imagenet_utils import preprocess_input
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Activation
from keras.layers import Conv2D, MaxPooling2D
from keras.models import Model

# %% [markdown]
# ### Getting a dataset
#
# The first step is going to be to load our data. As our example, we will be using the dataset [CalTech-101](http://www.vision.caltech.edu/Image_Datasets/Caltech101/), which contains around 9000 labeled images belonging to 101 object categories. However, we will exclude 5 of the categories which have the most images. This is in order to keep the class distribution fairly balanced (around 50-100) and constrained to a smaller number of images, around 6000.
#
# To obtain this dataset, you can either run the download script `download.sh` in the `data` folder, or the following commands:
#
#     wget http://www.vision.caltech.edu/Image_Datasets/Caltech101/101_ObjectCategories.tar.gz
#     tar -xvzf 101_ObjectCategories.tar.gz
#
# If you wish to use your own dataset, it should be aranged in the same fashion to `101_ObjectCategories` with all of the images organized into subfolders, one for each class. In this case, the following cell should load your custom dataset correctly by just replacing `root` with your folder. If you have an alternate structure, you just need to make sure that you load the list `data` where every element is a dict where `x` is the data (a 1-d numpy array) and `y` is the label (an integer). Use the helper function `get_image(path)` to load the image correctly into the array, and note also that the images are being resized to 224x224. This is necessary because the input to VGG16 is a 224x224 RGB image. You do not need to resize them on your hard drive, as that is being done in the code below.
#
# If you have `101_ObjectCategories` in your data folder, the following cell should load all the data.

# %%
# !echo "Downloading Hollywood celebrities for image notebooks"
# !curl -L -o celebrity.zip --progress-bar https://volei123floripa.s3.amazonaws.com/celebrity.zip
# !unzip celebrity.zip

#!rm -rf ./*
# !ls
# Out:
# Downloading Hollywood celebrities for image notebooks
# ############################################################################################# 100.0%
# Archive:  celebrity.zip
#    creating: celebrity/
#   inflating: __MACOSX/._celebrity
#   inflating: celebrity/.DS_Store
#   inflating: __MACOSX/celebrity/._.DS_Store
#    creating: celebrity/data/
#    creating: celebrity/data/Robert Downey Jr/
#   inflating: __MACOSX/celebrity/data/._Robert Downey Jr
#    creating: celebrity/data/Brad Pitt/
#   inflating: __MACOSX/celebrity/data/._Brad Pitt
#   inflating: celebrity/data/.DS_Store
#   inflating: __MACOSX/celebrity/data/._.DS_Store
#    creating: celebrity/data/Leonardo DiCaprio/
#   inflating: __MACOSX/celebrity/data/._Leonardo DiCaprio
#    creating: celebrity/data/Jennifer Lawrence/
#   inflating: __MACOSX/celebrity/data/._Jennifer Lawrence
#    creating: celebrity/data/Tom Cruise/
#   inflating: __MACOSX/celebrity/data/._Tom Cruise
#    creating: celebrity/data/Hugh Jackman/
#   inflating: __MACOSX/celebrity/data/._Hugh Jackman
#    creating: celebrity/data/Angelina Jolie/
#   inflating: __MACOSX/celebrity/data/._Angelina Jolie
#    creating: celebrity/data/Johnny Depp/
#   inflating: __MACOSX/celebrity/data/._Johnny Depp
#    creating: celebrity/data/Tom Hanks/
#   inflating: __MACOSX/celebrity/data/._Tom Hanks
#    creating: celebrity/data/Denzel Washington/
#   inflating: __MACOSX/celebrity/data/._Denzel Washington
#    creating: celebrity/data/Kate Winslet/
#   inflating: __MACOSX/celebrity/data/._Kate Winslet
#    creating: celebrity/data/Scarlett Johansson/
#   inflating: __MACOSX/celebrity/data/._Scarlett Johansson
#    creating: celebrity/data/Will Smith/
#   inflating: __MACOSX/celebrity/data/._Will Smith
#    creating: celebrity/data/Natalie Portman/
#   inflating: __MACOSX/celebrity/data/._Natalie Portman
#    creating: celebrity/data/Nicole Kidman/
#   inflating: __MACOSX/celebrity/data/._Nicole Kidman
#    creating: celebrity/data/Sandra Bullock/
#   inflating: __MACOSX/celebrity/data/._Sandra Bullock
#    creating: celebrity/data/Megan Fox/
#   inflating: __MACOSX/celebrity/data/._Megan Fox
#   inflating: celebrity/data/Robert Downey Jr/072_0dbe44e4.jpg
#   inflating: __MACOSX/celebrity/data/Robert Downey Jr/._072_0dbe44e4.jpg
#   inflating: celebrity/data/Robert Downey Jr/036_1b97e72c.jpg
#   inflating: __MACOSX/celebrity/data/Robert Downey Jr/._036_1b97e72c.jpg
#   inflating: celebrity/data/Robert Downey Jr/021_d1cfd3e9.jpg
#   inflating: __MACOSX/celebrity/data/Robert Downey Jr/._021_d1cfd3e9.jpg
#   inflating: celebrity/data/Robert Downey Jr/051_8bed72f0.jpg
#   inflating: __MACOSX/celebrity/data/Robert Downey Jr/._051_8bed72f0.jpg
#   inflating: celebrity/data/Robert Downey Jr/008_79cd0b7b.jpg
#   inflating: __MACOSX/celebrity/data/Robert Downey Jr/._008_79cd0b7b.jpg
#   inflating: celebrity/data/Robert Downey Jr/015_76c98a92.jpg
#   inflating: __MACOSX/celebrity/data/Robert Downey Jr/._015_76c98a92.jpg
#   inflating: celebrity/data/Robert Downey Jr/043_993b1247.jpg
#   inflating: __MACOSX/celebrity/data/Robert Downey Jr/._043_993b1247.jpg
#   inflating: celebrity/data/Robert Downey Jr/042_6ac9e24e.jpg
#   inflating: __MACOSX/celebrity/data/Robert Downey Jr/._042_6ac9e24e.jpg
#   inflating: celebrity/data/Robert Downey Jr/067_fb66d8ac.jpg
#   inflating: __MACOSX/celebrity/data/Robert Downey Jr/._067_fb66d8ac.jpg
#   inflating: celebrity/data/Robert Downey Jr/056_f2f25510.jpg
#   inflating: __MACOSX/celebrity/data/Robert Downey Jr/._056_f2f25510.jpg
#   inflating: celebrity/data/Robert Downey Jr/012_e3dd7d69.jpg
#   inflating: __MACOSX/celebrity/data/Robert Downey Jr/._012_e3dd7d69.jpg
#   inflating: celebrity/data/Robert Downey Jr/011_da108a07.jpg
#   inflating: __MACOSX/celebrity/data/Robert Downey Jr/._011_da108a07.jpg
#   inflating: celebrity/data/Robert Downey Jr/022_64141160.jpg
#   inflating: __MACOSX/celebrity/data/Robert Downey Jr/._022_64141160.jpg
#   inflating: celebrity/data/Robert Downey Jr/009_49237aa0.jpg
#   inflating: __MACOSX/celebrity/data/Robert Downey Jr/._009_49237aa0.jpg
#   inflating: celebrity/data/Robert Downey Jr/077_a908452a.jpg
#   inflating: __MACOSX/celebrity/data/Robert Downey Jr/._077_a908452a.jpg
#   inflating: celebrity/data/Robert Downey Jr/052_08084521.jpg
#   inflating: __MACOSX/celebrity/data/Robert Downey Jr/._052_08084521.jpg
#   inflating: celebrity/data/Robert Downey Jr/049_0f461a3e.jpg
#   inflating: __MACOSX/celebrity/data/Robert Downey Jr/._049_0f461a3e.jpg
#   inflating: celebrity/data/Robert Downey Jr/027_25f404f4.jpg
#   inflating: __MACOSX/celebrity/data/Robert Downey Jr/._027_25f404f4.jpg
#   inflating: celebrity/data/Robert Downey Jr/014_75f93e62.jpg
#   inflating: __MACOSX/celebrity/data/Robert Downey Jr/._014_75f93e62.jpg
#   inflating: celebrity/data/Robert Downey Jr/031_f2f3733f.jpg
#   inflating: __MACOSX/celebrity/data/Robert Downey Jr/._031_f2f3733f.jpg
#   inflating: celebrity/data/Robert Downey Jr/096_84100579.jpg
#   inflating: __MACOSX/celebrity/data/Robert Downey Jr/._096_84100579.jpg
#   inflating: celebrity/data/Robert Downey Jr/080_f5386479.jpg
#   inflating: __MACOSX/celebrity/data/Robert Downey Jr/._080_f5386479.jpg
#   inflating: celebrity/data/Robert Downey Jr/095_dd07ab81.jpg
#   inflating: __MACOSX/celebrity/data/Robert Downey Jr/._095_dd07ab81.jpg
#   inflating: celebrity/data/Robert Downey Jr/004_29776ffe.jpg
#   inflating: __MACOSX/celebrity/data/Robert Downey Jr/._004_29776ffe.jpg
#   inflating: celebrity/data/Robert Downey Jr/019_ac261615.jpg
#   inflating: __MACOSX/celebrity/data/Robert Downey Jr/._019_ac261615.jpg
#   inflating: celebrity/data/Robert Downey Jr/058_4ed85318.jpg
#   inflating: __MACOSX/celebrity/data/Robert Downey Jr/._058_4ed85318.jpg
#   inflating: celebrity/data/Robert Downey Jr/044_faec2086.jpg
#   inflating: __MACOSX/celebrity/data/Robert Downey Jr/._044_faec2086.jpg
#   inflating: celebrity/data/Robert Downey Jr/032_ac85b92c.jpg
#   inflating: __MACOSX/celebrity/data/Robert Downey Jr/._032_ac85b92c.jpg
#   inflating: celebrity/data/Robert Downey Jr/086_9b44c502.jpg
#   inflating: __MACOSX/celebrity/data/Robert Downey Jr/._086_9b44c502.jpg
#   inflating: celebrity/data/Robert Downey Jr/046_a658cf42.jpg
#   inflating: __MACOSX/celebrity/data/Robert Downey Jr/._046_a658cf42.jpg
#   inflating: celebrity/data/Robert Downey Jr/097_833dba65.jpg
#   inflating: __MACOSX/celebrity/data/Robert Downey Jr/._097_833dba65.jpg
#   inflating: celebrity/data/Robert Downey Jr/002_cc92e159.jpg
#   inflating: __MACOSX/celebrity/data/Robert Downey Jr/._002_cc92e159.jpg
#   inflating: celebrity/data/Robert Downey Jr/059_01c01e72.jpg
#   inflating: __MACOSX/celebrity/data/Robert Downey Jr/._059_01c01e72.jpg
#   inflating: celebrity/data/Robert Downey Jr/048_d7765620.jpg
#   inflating: __MACOSX/celebrity/data/Robert Downey Jr/._048_d7765620.jpg
#   inflating: celebrity/data/Robert Downey Jr/041_b77c7671.jpg
#   inflating: __MACOSX/celebrity/data/Robert Downey Jr/._041_b77c7671.jpg
#   inflating: celebrity/data/Robert Downey Jr/024_db7504a3.jpg
#   inflating: __MACOSX/celebrity/data/Robert Downey Jr/._024_db7504a3.jpg
#   inflating: celebrity/data/Robert Downey Jr/076_318ed434.jpg
#   inflating: __MACOSX/celebrity/data/Robert Downey Jr/._076_318ed434.jpg
#   inflating: celebrity/data/Robert Downey Jr/040_91c31d91.jpg
#   inflating: __MACOSX/celebrity/data/Robert Downey Jr/._040_91c31d91.jpg
#   inflating: celebrity/data/Robert Downey Jr/037_342fdd2c.jpg
#   inflating: __MACOSX/celebrity/data/Robert Downey Jr/._037_342fdd2c.jpg
#   inflating: celebrity/data/Robert Downey Jr/099_0d04ca3f.jpg
#   inflating: __MACOSX/celebrity/data/Robert Downey Jr/._099_0d04ca3f.jpg
#   inflating: celebrity/data/Robert Downey Jr/082_d9295121.jpg
#   inflating: __MACOSX/celebrity/data/Robert Downey Jr/._082_d9295121.jpg
#   inflating: celebrity/data/Robert Downey Jr/087_7c6523e6.jpg
#   inflating: __MACOSX/celebrity/data/Robert Downey Jr/._087_7c6523e6.jpg
#   inflating: celebrity/data/Robert Downey Jr/075_dff1c336.jpg
#   inflating: __MACOSX/celebrity/data/Robert Downey Jr/._075_dff1c336.jpg
#   inflating: celebrity/data/Robert Downey Jr/034_71739e5a.jpg
#   inflating: __MACOSX/celebrity/data/Robert Downey Jr/._034_71739e5a.jpg
#   inflating: celebrity/data/Robert Downey Jr/064_9ac818ed.jpg
#   inflating: __MACOSX/celebrity/data/Robert Downey Jr/._064_9ac818ed.jpg
#   inflating: celebrity/data/Robert Downey Jr/079_91098298.jpg
#   inflating: __MACOSX/celebrity/data/Robert Downey Jr/._079_91098298.jpg
#   inflating: celebrity/data/Robert Downey Jr/100_dcb749ca.jpg
#   inflating: __MACOSX/celebrity/data/Robert Downey Jr/._100_dcb749ca.jpg
#   inflating: celebrity/data/Robert Downey Jr/006_c26122bd.jpg
#   inflating: __MACOSX/celebrity/data/Robert Downey Jr/._006_c26122bd.jpg
#   inflating: celebrity/data/Robert Downey Jr/057_8572457a.jpg
#   inflating: __MACOSX/celebrity/data/Robert Downey Jr/._057_8572457a.jpg
#   inflating: celebrity/data/Robert Downey Jr/071_a9b71352.jpg
#   inflating: __MACOSX/celebrity/data/Robert Downey Jr/._071_a9b71352.jpg
#   inflating: celebrity/data/Robert Downey Jr/013_9e49009e.jpg
#   inflating: __MACOSX/celebrity/data/Robert Downey Jr/._013_9e49009e.jpg
#   inflating: celebrity/data/Robert Downey Jr/033_255948c8.jpg
#   inflating: __MACOSX/celebrity/data/Robert Downey Jr/._033_255948c8.jpg
#   inflating: celebrity/data/Robert Downey Jr/089_b11d4b97.jpg
#   inflating: __MACOSX/celebrity/data/Robert Downey Jr/._089_b11d4b97.jpg
#   inflating: celebrity/data/Robert Downey Jr/035_e4be5129.jpg
#   inflating: __MACOSX/celebrity/data/Robert Downey Jr/._035_e4be5129.jpg
#   inflating: celebrity/data/Robert Downey Jr/001_a51bb26a.jpg
#   inflating: __MACOSX/celebrity/data/Robert Downey Jr/._001_a51bb26a.jpg
#   inflating: celebrity/data/Robert Downey Jr/039_bfbbf1e4.jpg
#   inflating: __MACOSX/celebrity/data/Robert Downey Jr/._039_bfbbf1e4.jpg
#   inflating: celebrity/data/Robert Downey Jr/003_e18853f8.jpg
#   inflating: __MACOSX/celebrity/data/Robert Downey Jr/._003_e18853f8.jpg
#   inflating: celebrity/data/Robert Downey Jr/005_8af3cada.jpg
#   inflating: __MACOSX/celebrity/data/Robert Downey Jr/._005_8af3cada.jpg
#   inflating: celebrity/data/Robert Downey Jr/065_343bfe69.jpg
#   inflating: __MACOSX/celebrity/data/Robert Downey Jr/._065_343bfe69.jpg
#   inflating: celebrity/data/Robert Downey Jr/010_991a88dc.jpg
#   inflating: __MACOSX/celebrity/data/Robert Downey Jr/._010_991a88dc.jpg
#   inflating: celebrity/data/Robert Downey Jr/055_51880515.jpg
#   inflating: __MACOSX/celebrity/data/Robert Downey Jr/._055_51880515.jpg
#   inflating: celebrity/data/Robert Downey Jr/074_a86aab43.jpg
#   inflating: __MACOSX/celebrity/data/Robert Downey Jr/._074_a86aab43.jpg
#   inflating: celebrity/data/Robert Downey Jr/084_f5991991.jpg
#   inflating: __MACOSX/celebrity/data/Robert Downey Jr/._084_f5991991.jpg
#   inflating: celebrity/data/Robert Downey Jr/093_8bbca2a0.jpg
#   inflating: __MACOSX/celebrity/data/Robert Downey Jr/._093_8bbca2a0.jpg
#   inflating: celebrity/data/Robert Downey Jr/091_5307a177.jpg
#   inflating: __MACOSX/celebrity/data/Robert Downey Jr/._091_5307a177.jpg
#   inflating: celebrity/data/Robert Downey Jr/073_9d58f7ef.jpg
#   inflating: __MACOSX/celebrity/data/Robert Downey Jr/._073_9d58f7ef.jpg
#   inflating: celebrity/data/Robert Downey Jr/025_467e0866.jpg
#   inflating: __MACOSX/celebrity/data/Robert Downey Jr/._025_467e0866.jpg
#   inflating: celebrity/data/Robert Downey Jr/062_81d4fb18.jpg
#   inflating: __MACOSX/celebrity/data/Robert Downey Jr/._062_81d4fb18.jpg
#   inflating: celebrity/data/Robert Downey Jr/020_b12140b8.jpg
#   inflating: __MACOSX/celebrity/data/Robert Downey Jr/._020_b12140b8.jpg
#   inflating: celebrity/data/Robert Downey Jr/016_375490e8.jpg
#   inflating: __MACOSX/celebrity/data/Robert Downey Jr/._016_375490e8.jpg
#   inflating: celebrity/data/Robert Downey Jr/090_d347e279.jpg
#   inflating: __MACOSX/celebrity/data/Robert Downey Jr/._090_d347e279.jpg
#   inflating: celebrity/data/Robert Downey Jr/045_caf1e891.jpg
#   inflating: __MACOSX/celebrity/data/Robert Downey Jr/._045_caf1e891.jpg
#   inflating: celebrity/data/Robert Downey Jr/066_0bdb9ac3.jpg
#   inflating: __MACOSX/celebrity/data/Robert Downey Jr/._066_0bdb9ac3.jpg
#   inflating: celebrity/data/Robert Downey Jr/092_c27c41de.jpg
#   inflating: __MACOSX/celebrity/data/Robert Downey Jr/._092_c27c41de.jpg
#   inflating: celebrity/data/Robert Downey Jr/047_389fe7b8.jpg
#   inflating: __MACOSX/celebrity/data/Robert Downey Jr/._047_389fe7b8.jpg
#   inflating: celebrity/data/Robert Downey Jr/023_51dce41c.jpg
#   inflating: __MACOSX/celebrity/data/Robert Downey Jr/._023_51dce41c.jpg
#   inflating: celebrity/data/Robert Downey Jr/026_76e88f4c.jpg
#   inflating: __MACOSX/celebrity/data/Robert Downey Jr/._026_76e88f4c.jpg
#   inflating: celebrity/data/Robert Downey Jr/017_fd82d064.jpg
#   inflating: __MACOSX/celebrity/data/Robert Downey Jr/._017_fd82d064.jpg
#   inflating: celebrity/data/Robert Downey Jr/070_6192068e.jpg
#   inflating: __MACOSX/celebrity/data/Robert Downey Jr/._070_6192068e.jpg
#   inflating: celebrity/data/Robert Downey Jr/038_165ebb58.jpg
#   inflating: __MACOSX/celebrity/data/Robert Downey Jr/._038_165ebb58.jpg
#   inflating: celebrity/data/Robert Downey Jr/018_0d23eccd.jpg
#   inflating: __MACOSX/celebrity/data/Robert Downey Jr/._018_0d23eccd.jpg
#   inflating: celebrity/data/Robert Downey Jr/061_b36635a2.jpg
#   inflating: __MACOSX/celebrity/data/Robert Downey Jr/._061_b36635a2.jpg
#   inflating: celebrity/data/Robert Downey Jr/007_ecb8599e.jpg
#   inflating: __MACOSX/celebrity/data/Robert Downey Jr/._007_ecb8599e.jpg
#   inflating: celebrity/data/Robert Downey Jr/054_d500397d.jpg
#   inflating: __MACOSX/celebrity/data/Robert Downey Jr/._054_d500397d.jpg
#   inflating: celebrity/data/Robert Downey Jr/028_10053075.jpg
#   inflating: __MACOSX/celebrity/data/Robert Downey Jr/._028_10053075.jpg
#   inflating: celebrity/data/Robert Downey Jr/030_adb3aa0e.jpg
#   inflating: __MACOSX/celebrity/data/Robert Downey Jr/._030_adb3aa0e.jpg
#   inflating: celebrity/data/Robert Downey Jr/094_087829ab.jpg
#   inflating: __MACOSX/celebrity/data/Robert Downey Jr/._094_087829ab.jpg
#   inflating: celebrity/data/Robert Downey Jr/060_19a80cff.jpg
#   inflating: __MACOSX/celebrity/data/Robert Downey Jr/._060_19a80cff.jpg
#   inflating: celebrity/data/Robert Downey Jr/053_8075590e.jpg
#   inflating: __MACOSX/celebrity/data/Robert Downey Jr/._053_8075590e.jpg
#   inflating: celebrity/data/Robert Downey Jr/081_725684cb.jpg
#   inflating: __MACOSX/celebrity/data/Robert Downey Jr/._081_725684cb.jpg
#   inflating: celebrity/data/Robert Downey Jr/083_f284dc2b.jpg
#   inflating: __MACOSX/celebrity/data/Robert Downey Jr/._083_f284dc2b.jpg
#   inflating: celebrity/data/Robert Downey Jr/069_0548213f.jpg
#   inflating: __MACOSX/celebrity/data/Robert Downey Jr/._069_0548213f.jpg
#   inflating: celebrity/data/Robert Downey Jr/068_72330c63.jpg
#   inflating: __MACOSX/celebrity/data/Robert Downey Jr/._068_72330c63.jpg
#   inflating: celebrity/data/Robert Downey Jr/029_02077e81.jpg
#   inflating: __MACOSX/celebrity/data/Robert Downey Jr/._029_02077e81.jpg
#   inflating: celebrity/data/Robert Downey Jr/098_b78efdc8.jpg
#   inflating: __MACOSX/celebrity/data/Robert Downey Jr/._098_b78efdc8.jpg
#   inflating: celebrity/data/Robert Downey Jr/085_b44c8d35.jpg
#   inflating: __MACOSX/celebrity/data/Robert Downey Jr/._085_b44c8d35.jpg
#   inflating: celebrity/data/Robert Downey Jr/063_fe99146b.jpg
#   inflating: __MACOSX/celebrity/data/Robert Downey Jr/._063_fe99146b.jpg
#   inflating: celebrity/data/Robert Downey Jr/088_ff699567.jpg
#   inflating: __MACOSX/celebrity/data/Robert Downey Jr/._088_ff699567.jpg
#   inflating: celebrity/data/Robert Downey Jr/050_7509d1bb.jpg
#   inflating: __MACOSX/celebrity/data/Robert Downey Jr/._050_7509d1bb.jpg
#   inflating: celebrity/data/Robert Downey Jr/078_adefb117.jpg
#   inflating: __MACOSX/celebrity/data/Robert Downey Jr/._078_adefb117.jpg
#   inflating: celebrity/data/Brad Pitt/090_12e1f614.jpg
#   inflating: __MACOSX/celebrity/data/Brad Pitt/._090_12e1f614.jpg
#   inflating: celebrity/data/Brad Pitt/055_14a5e7bc.jpg
#   inflating: __MACOSX/celebrity/data/Brad Pitt/._055_14a5e7bc.jpg
#   inflating: celebrity/data/Brad Pitt/084_4876da64.jpg
#   inflating: __MACOSX/celebrity/data/Brad Pitt/._084_4876da64.jpg
#   inflating: celebrity/data/Brad Pitt/067_571d88eb.jpg
#   inflating: __MACOSX/celebrity/data/Brad Pitt/._067_571d88eb.jpg
#   inflating: celebrity/data/Brad Pitt/064_213e2850.jpg
#   inflating: __MACOSX/celebrity/data/Brad Pitt/._064_213e2850.jpg
#   inflating: celebrity/data/Brad Pitt/025_25dc7dcf.jpg
#   inflating: __MACOSX/celebrity/data/Brad Pitt/._025_25dc7dcf.jpg
#   inflating: celebrity/data/Brad Pitt/014_871b0d80.jpg
#   inflating: __MACOSX/celebrity/data/Brad Pitt/._014_871b0d80.jpg
#   inflating: celebrity/data/Brad Pitt/079_e3171916.jpg
#   inflating: __MACOSX/celebrity/data/Brad Pitt/._079_e3171916.jpg
#   inflating: celebrity/data/Brad Pitt/060_136e5ef5.jpg
#   inflating: __MACOSX/celebrity/data/Brad Pitt/._060_136e5ef5.jpg
#   inflating: celebrity/data/Brad Pitt/072_da45cf8f.jpg
#   inflating: __MACOSX/celebrity/data/Brad Pitt/._072_da45cf8f.jpg
#   inflating: celebrity/data/Brad Pitt/034_984e63b3.jpg
#   inflating: __MACOSX/celebrity/data/Brad Pitt/._034_984e63b3.jpg
#   inflating: celebrity/data/Brad Pitt/027_78f200c3.jpg
#   inflating: __MACOSX/celebrity/data/Brad Pitt/._027_78f200c3.jpg
#   inflating: celebrity/data/Brad Pitt/061_38d21dc0.jpg
#   inflating: __MACOSX/celebrity/data/Brad Pitt/._061_38d21dc0.jpg
#   inflating: celebrity/data/Brad Pitt/019_ddcd5687.jpg
#   inflating: __MACOSX/celebrity/data/Brad Pitt/._019_ddcd5687.jpg
#   inflating: celebrity/data/Brad Pitt/010_08c44431.jpg
#   inflating: __MACOSX/celebrity/data/Brad Pitt/._010_08c44431.jpg
#   inflating: celebrity/data/Brad Pitt/100_f4b2c7a7.jpg
#   inflating: __MACOSX/celebrity/data/Brad Pitt/._100_f4b2c7a7.jpg
#   inflating: celebrity/data/Brad Pitt/091_8561b34e.jpg
#   inflating: __MACOSX/celebrity/data/Brad Pitt/._091_8561b34e.jpg
#   inflating: celebrity/data/Brad Pitt/098_36dd62c5.jpg
#   inflating: __MACOSX/celebrity/data/Brad Pitt/._098_36dd62c5.jpg
#   inflating: celebrity/data/Brad Pitt/099_151b7575.jpg
#   inflating: __MACOSX/celebrity/data/Brad Pitt/._099_151b7575.jpg
#   inflating: celebrity/data/Brad Pitt/036_5e0af3bf.jpg
#   inflating: __MACOSX/celebrity/data/Brad Pitt/._036_5e0af3bf.jpg
#   inflating: celebrity/data/Brad Pitt/077_ddf0abd8.jpg
#   inflating: __MACOSX/celebrity/data/Brad Pitt/._077_ddf0abd8.jpg
#   inflating: celebrity/data/Brad Pitt/052_b80b0a3f.jpg
#   inflating: __MACOSX/celebrity/data/Brad Pitt/._052_b80b0a3f.jpg
#   inflating: celebrity/data/Brad Pitt/021_143b276f.jpg
#   inflating: __MACOSX/celebrity/data/Brad Pitt/._021_143b276f.jpg
#   inflating: celebrity/data/Brad Pitt/006_87166f38.jpg
#   inflating: __MACOSX/celebrity/data/Brad Pitt/._006_87166f38.jpg
#   inflating: celebrity/data/Brad Pitt/026_805241a7.jpg
#   inflating: __MACOSX/celebrity/data/Brad Pitt/._026_805241a7.jpg
#   inflating: celebrity/data/Brad Pitt/045_6895fe7e.jpg
#   inflating: __MACOSX/celebrity/data/Brad Pitt/._045_6895fe7e.jpg
#   inflating: celebrity/data/Brad Pitt/074_6f4720aa.jpg
#   inflating: __MACOSX/celebrity/data/Brad Pitt/._074_6f4720aa.jpg
#   inflating: celebrity/data/Brad Pitt/088_b1977c95.jpg
#   inflating: __MACOSX/celebrity/data/Brad Pitt/._088_b1977c95.jpg
#   inflating: celebrity/data/Brad Pitt/003_7a6b2156.jpg
#   inflating: __MACOSX/celebrity/data/Brad Pitt/._003_7a6b2156.jpg
#   inflating: celebrity/data/Brad Pitt/097_df404aa1.jpg
#   inflating: __MACOSX/celebrity/data/Brad Pitt/._097_df404aa1.jpg
#   inflating: celebrity/data/Brad Pitt/015_82889ec9.jpg
#   inflating: __MACOSX/celebrity/data/Brad Pitt/._015_82889ec9.jpg
#   inflating: celebrity/data/Brad Pitt/011_270cd3ea.jpg
#   inflating: __MACOSX/celebrity/data/Brad Pitt/._011_270cd3ea.jpg
#   inflating: celebrity/data/Brad Pitt/078_b546dff5.jpg
#   inflating: __MACOSX/celebrity/data/Brad Pitt/._078_b546dff5.jpg
#   inflating: celebrity/data/Brad Pitt/076_75b9dd73.jpg
#   inflating: __MACOSX/celebrity/data/Brad Pitt/._076_75b9dd73.jpg
#   inflating: celebrity/data/Brad Pitt/028_181cbb8a.jpg
#   inflating: __MACOSX/celebrity/data/Brad Pitt/._028_181cbb8a.jpg
#   inflating: celebrity/data/Brad Pitt/062_f0c8d0c8.jpg
#   inflating: __MACOSX/celebrity/data/Brad Pitt/._062_f0c8d0c8.jpg
#   inflating: celebrity/data/Brad Pitt/073_aa4e37e8.jpg
#   inflating: __MACOSX/celebrity/data/Brad Pitt/._073_aa4e37e8.jpg
#   inflating: celebrity/data/Brad Pitt/017_4748675b.jpg
#   inflating: __MACOSX/celebrity/data/Brad Pitt/._017_4748675b.jpg
#   inflating: celebrity/data/Brad Pitt/012_8de7a736.jpg
#   inflating: __MACOSX/celebrity/data/Brad Pitt/._012_8de7a736.jpg
#   inflating: celebrity/data/Brad Pitt/092_22d9de5d.jpg
#   inflating: __MACOSX/celebrity/data/Brad Pitt/._092_22d9de5d.jpg
#   inflating: celebrity/data/Brad Pitt/035_a767728d.jpg
#   inflating: __MACOSX/celebrity/data/Brad Pitt/._035_a767728d.jpg
#   inflating: celebrity/data/Brad Pitt/050_3e39c960.jpg
#   inflating: __MACOSX/celebrity/data/Brad Pitt/._050_3e39c960.jpg
#   inflating: celebrity/data/Brad Pitt/048_185402c6.jpg
#   inflating: __MACOSX/celebrity/data/Brad Pitt/._048_185402c6.jpg
#   inflating: celebrity/data/Brad Pitt/058_ca613f72.jpg
#   inflating: __MACOSX/celebrity/data/Brad Pitt/._058_ca613f72.jpg
#   inflating: celebrity/data/Brad Pitt/056_8362ff51.jpg
#   inflating: __MACOSX/celebrity/data/Brad Pitt/._056_8362ff51.jpg
#   inflating: celebrity/data/Brad Pitt/020_45c8d790.jpg
#   inflating: __MACOSX/celebrity/data/Brad Pitt/._020_45c8d790.jpg
#   inflating: celebrity/data/Brad Pitt/075_a7a83d60.jpg
#   inflating: __MACOSX/celebrity/data/Brad Pitt/._075_a7a83d60.jpg
#   inflating: celebrity/data/Brad Pitt/001_c04300ef.jpg
#   inflating: __MACOSX/celebrity/data/Brad Pitt/._001_c04300ef.jpg
#   inflating: celebrity/data/Brad Pitt/053_be062c12.jpg
#   inflating: __MACOSX/celebrity/data/Brad Pitt/._053_be062c12.jpg
#   inflating: celebrity/data/Brad Pitt/016_8bb23f7e.jpg
#   inflating: __MACOSX/celebrity/data/Brad Pitt/._016_8bb23f7e.jpg
#   inflating: celebrity/data/Brad Pitt/082_545afee5.jpg
#   inflating: __MACOSX/celebrity/data/Brad Pitt/._082_545afee5.jpg
#   inflating: celebrity/data/Brad Pitt/042_8030e553.jpg
#   inflating: __MACOSX/celebrity/data/Brad Pitt/._042_8030e553.jpg
#   inflating: celebrity/data/Brad Pitt/037_b5467841.jpg
#   inflating: __MACOSX/celebrity/data/Brad Pitt/._037_b5467841.jpg
#   inflating: celebrity/data/Brad Pitt/041_cc0957bf.jpg
#   inflating: __MACOSX/celebrity/data/Brad Pitt/._041_cc0957bf.jpg
#   inflating: celebrity/data/Brad Pitt/002_cc1b9701.jpg
#   inflating: __MACOSX/celebrity/data/Brad Pitt/._002_cc1b9701.jpg
#   inflating: celebrity/data/Brad Pitt/023_98d91529.jpg
#   inflating: __MACOSX/celebrity/data/Brad Pitt/._023_98d91529.jpg
#   inflating: celebrity/data/Brad Pitt/007_74ccfb4a.jpg
#   inflating: __MACOSX/celebrity/data/Brad Pitt/._007_74ccfb4a.jpg
#   inflating: celebrity/data/Brad Pitt/054_9f01aefa.jpg
#   inflating: __MACOSX/celebrity/data/Brad Pitt/._054_9f01aefa.jpg
#   inflating: celebrity/data/Brad Pitt/039_1c018deb.jpg
#   inflating: __MACOSX/celebrity/data/Brad Pitt/._039_1c018deb.jpg
#   inflating: celebrity/data/Brad Pitt/038_5e10a567.jpg
#   inflating: __MACOSX/celebrity/data/Brad Pitt/._038_5e10a567.jpg
#   inflating: celebrity/data/Brad Pitt/071_2d51687a.jpg
#   inflating: __MACOSX/celebrity/data/Brad Pitt/._071_2d51687a.jpg
#   inflating: celebrity/data/Brad Pitt/013_0c83ca91.jpg
#   inflating: __MACOSX/celebrity/data/Brad Pitt/._013_0c83ca91.jpg
#   inflating: celebrity/data/Brad Pitt/096_b096ebfe.jpg
#   inflating: __MACOSX/celebrity/data/Brad Pitt/._096_b096ebfe.jpg
#   inflating: celebrity/data/Brad Pitt/032_fd37a8e2.jpg
#   inflating: __MACOSX/celebrity/data/Brad Pitt/._032_fd37a8e2.jpg
#   inflating: celebrity/data/Brad Pitt/005_02ab3a1b.jpg
#   inflating: __MACOSX/celebrity/data/Brad Pitt/._005_02ab3a1b.jpg
#   inflating: celebrity/data/Brad Pitt/059_ef2c0ca7.jpg
#   inflating: __MACOSX/celebrity/data/Brad Pitt/._059_ef2c0ca7.jpg
#   inflating: celebrity/data/Brad Pitt/018_136dbb40.jpg
#   inflating: __MACOSX/celebrity/data/Brad Pitt/._018_136dbb40.jpg
#   inflating: celebrity/data/Brad Pitt/057_545ca96d.jpg
#   inflating: __MACOSX/celebrity/data/Brad Pitt/._057_545ca96d.jpg
#   inflating: celebrity/data/Brad Pitt/094_16e562f0.jpg
#   inflating: __MACOSX/celebrity/data/Brad Pitt/._094_16e562f0.jpg
#   inflating: celebrity/data/Brad Pitt/043_6973a308.jpg
#   inflating: __MACOSX/celebrity/data/Brad Pitt/._043_6973a308.jpg
#   inflating: celebrity/data/Brad Pitt/031_8fc10a75.jpg
#   inflating: __MACOSX/celebrity/data/Brad Pitt/._031_8fc10a75.jpg
#   inflating: celebrity/data/Brad Pitt/089_7a7d2c5d.jpg
#   inflating: __MACOSX/celebrity/data/Brad Pitt/._089_7a7d2c5d.jpg
#   inflating: celebrity/data/Brad Pitt/093_c4d318cd.jpg
#   inflating: __MACOSX/celebrity/data/Brad Pitt/._093_c4d318cd.jpg
#   inflating: celebrity/data/Brad Pitt/069_8533eee4.jpg
#   inflating: __MACOSX/celebrity/data/Brad Pitt/._069_8533eee4.jpg
#   inflating: celebrity/data/Brad Pitt/049_31625c44.jpg
#   inflating: __MACOSX/celebrity/data/Brad Pitt/._049_31625c44.jpg
#   inflating: celebrity/data/Brad Pitt/008_31e90c6b.jpg
#   inflating: __MACOSX/celebrity/data/Brad Pitt/._008_31e90c6b.jpg
#   inflating: celebrity/data/Brad Pitt/009_23c94f29.jpg
#   inflating: __MACOSX/celebrity/data/Brad Pitt/._009_23c94f29.jpg
#   inflating: celebrity/data/Brad Pitt/030_716e4856.jpg
#   inflating: __MACOSX/celebrity/data/Brad Pitt/._030_716e4856.jpg
#   inflating: celebrity/data/Brad Pitt/033_46c95715.jpg
#   inflating: __MACOSX/celebrity/data/Brad Pitt/._033_46c95715.jpg
#   inflating: celebrity/data/Brad Pitt/081_4d677d83.jpg
#   inflating: __MACOSX/celebrity/data/Brad Pitt/._081_4d677d83.jpg
#   inflating: celebrity/data/Brad Pitt/044_ac060de4.jpg
#   inflating: __MACOSX/celebrity/data/Brad Pitt/._044_ac060de4.jpg
#   inflating: celebrity/data/Brad Pitt/087_155f1f74.jpg
#   inflating: __MACOSX/celebrity/data/Brad Pitt/._087_155f1f74.jpg
#   inflating: celebrity/data/Brad Pitt/024_54112f36.jpg
#   inflating: __MACOSX/celebrity/data/Brad Pitt/._024_54112f36.jpg
#   inflating: celebrity/data/Brad Pitt/065_34848907.jpg
#   inflating: __MACOSX/celebrity/data/Brad Pitt/._065_34848907.jpg
#   inflating: celebrity/data/Brad Pitt/066_1867585d.jpg
#   inflating: __MACOSX/celebrity/data/Brad Pitt/._066_1867585d.jpg
#   inflating: celebrity/data/Brad Pitt/046_8bf34269.jpg
#   inflating: __MACOSX/celebrity/data/Brad Pitt/._046_8bf34269.jpg
#   inflating: celebrity/data/Brad Pitt/085_5c4b6432.jpg
#   inflating: __MACOSX/celebrity/data/Brad Pitt/._085_5c4b6432.jpg
#   inflating: celebrity/data/Brad Pitt/068_5ebbf7fb.jpg
#   inflating: __MACOSX/celebrity/data/Brad Pitt/._068_5ebbf7fb.jpg
#   inflating: celebrity/data/Brad Pitt/040_9b4bfe5b.jpg
#   inflating: __MACOSX/celebrity/data/Brad Pitt/._040_9b4bfe5b.jpg
#   inflating: celebrity/data/Brad Pitt/029_36dac19e.jpg
#   inflating: __MACOSX/celebrity/data/Brad Pitt/._029_36dac19e.jpg
#   inflating: celebrity/data/Brad Pitt/070_0acb9d53.jpg
#   inflating: __MACOSX/celebrity/data/Brad Pitt/._070_0acb9d53.jpg
#   inflating: celebrity/data/Brad Pitt/080_569bb446.jpg
#   inflating: __MACOSX/celebrity/data/Brad Pitt/._080_569bb446.jpg
#   inflating: celebrity/data/Brad Pitt/047_80045019.jpg
#   inflating: __MACOSX/celebrity/data/Brad Pitt/._047_80045019.jpg
#   inflating: celebrity/data/Brad Pitt/022_a8206d1a.jpg
#   inflating: __MACOSX/celebrity/data/Brad Pitt/._022_a8206d1a.jpg
#   inflating: celebrity/data/Brad Pitt/086_8274c0d1.jpg
#   inflating: __MACOSX/celebrity/data/Brad Pitt/._086_8274c0d1.jpg
#   inflating: celebrity/data/Brad Pitt/095_1104d364.jpg
#   inflating: __MACOSX/celebrity/data/Brad Pitt/._095_1104d364.jpg
#   inflating: celebrity/data/Brad Pitt/051_fd8a292f.jpg
#   inflating: __MACOSX/celebrity/data/Brad Pitt/._051_fd8a292f.jpg
#   inflating: celebrity/data/Brad Pitt/083_d6f1d5ac.jpg
#   inflating: __MACOSX/celebrity/data/Brad Pitt/._083_d6f1d5ac.jpg
#   inflating: celebrity/data/Brad Pitt/063_a90951c4.jpg
#   inflating: __MACOSX/celebrity/data/Brad Pitt/._063_a90951c4.jpg
#   inflating: celebrity/data/Brad Pitt/004_777c50d0.jpg
#   inflating: __MACOSX/celebrity/data/Brad Pitt/._004_777c50d0.jpg
#   inflating: celebrity/data/Leonardo DiCaprio/084_08314073.jpg
#   inflating: __MACOSX/celebrity/data/Leonardo DiCaprio/._084_08314073.jpg
#   inflating: celebrity/data/Leonardo DiCaprio/046_db08e5f7.jpg
#   inflating: __MACOSX/celebrity/data/Leonardo DiCaprio/._046_db08e5f7.jpg
#   inflating: celebrity/data/Leonardo DiCaprio/015_2872d02b.jpg
#   inflating: __MACOSX/celebrity/data/Leonardo DiCaprio/._015_2872d02b.jpg
#   inflating: celebrity/data/Leonardo DiCaprio/001_08194468.jpg
#   inflating: __MACOSX/celebrity/data/Leonardo DiCaprio/._001_08194468.jpg
#   inflating: celebrity/data/Leonardo DiCaprio/018_2c458568.jpg
#   inflating: __MACOSX/celebrity/data/Leonardo DiCaprio/._018_2c458568.jpg
#   inflating: celebrity/data/Leonardo DiCaprio/017_51311450.jpg
#   inflating: __MACOSX/celebrity/data/Leonardo DiCaprio/._017_51311450.jpg
#   inflating: celebrity/data/Leonardo DiCaprio/005_7fe5b764.jpg
#   inflating: __MACOSX/celebrity/data/Leonardo DiCaprio/._005_7fe5b764.jpg
#   inflating: celebrity/data/Leonardo DiCaprio/061_57c86521.jpg
#   inflating: __MACOSX/celebrity/data/Leonardo DiCaprio/._061_57c86521.jpg
#   inflating: celebrity/data/Leonardo DiCaprio/024_bf83d073.jpg
#   inflating: __MACOSX/celebrity/data/Leonardo DiCaprio/._024_bf83d073.jpg
#   inflating: celebrity/data/Leonardo DiCaprio/055_ba4ace00.jpg
#   inflating: __MACOSX/celebrity/data/Leonardo DiCaprio/._055_ba4ace00.jpg
#   inflating: celebrity/data/Leonardo DiCaprio/071_a052296d.jpg
#   inflating: __MACOSX/celebrity/data/Leonardo DiCaprio/._071_a052296d.jpg
#   inflating: celebrity/data/Leonardo DiCaprio/097_1837d89e.jpg
#   inflating: __MACOSX/celebrity/data/Leonardo DiCaprio/._097_1837d89e.jpg
#   inflating: celebrity/data/Leonardo DiCaprio/066_f048ba09.jpg
#   inflating: __MACOSX/celebrity/data/Leonardo DiCaprio/._066_f048ba09.jpg
#   inflating: celebrity/data/Leonardo DiCaprio/057_f0c37eee.jpg
#   inflating: __MACOSX/celebrity/data/Leonardo DiCaprio/._057_f0c37eee.jpg
#   inflating: celebrity/data/Leonardo DiCaprio/056_13edab75.jpg
#   inflating: __MACOSX/celebrity/data/Leonardo DiCaprio/._056_13edab75.jpg
#   inflating: celebrity/data/Leonardo DiCaprio/089_8e7757ef.jpg
#   inflating: __MACOSX/celebrity/data/Leonardo DiCaprio/._089_8e7757ef.jpg
#   inflating: celebrity/data/Leonardo DiCaprio/080_2bffea0b.jpg
#   inflating: __MACOSX/celebrity/data/Leonardo DiCaprio/._080_2bffea0b.jpg
#   inflating: celebrity/data/Leonardo DiCaprio/004_af012af1.jpg
#   inflating: __MACOSX/celebrity/data/Leonardo DiCaprio/._004_af012af1.jpg
#   inflating: celebrity/data/Leonardo DiCaprio/074_2b2a84b6.jpg
#   inflating: __MACOSX/celebrity/data/Leonardo DiCaprio/._074_2b2a84b6.jpg
#   inflating: celebrity/data/Leonardo DiCaprio/064_397fd4d4.jpg
#   inflating: __MACOSX/celebrity/data/Leonardo DiCaprio/._064_397fd4d4.jpg
#   inflating: celebrity/data/Leonardo DiCaprio/085_a292bf25.jpg
#   inflating: __MACOSX/celebrity/data/Leonardo DiCaprio/._085_a292bf25.jpg
#   inflating: celebrity/data/Leonardo DiCaprio/012_d7aea1e6.jpg
#   inflating: __MACOSX/celebrity/data/Leonardo DiCaprio/._012_d7aea1e6.jpg
#   inflating: celebrity/data/Leonardo DiCaprio/095_7ffaffe6.jpg
#   inflating: __MACOSX/celebrity/data/Leonardo DiCaprio/._095_7ffaffe6.jpg
#   inflating: celebrity/data/Leonardo DiCaprio/026_ecbdaaa7.jpg
#   inflating: __MACOSX/celebrity/data/Leonardo DiCaprio/._026_ecbdaaa7.jpg
#   inflating: celebrity/data/Leonardo DiCaprio/068_a703f85f.jpg
#   inflating: __MACOSX/celebrity/data/Leonardo DiCaprio/._068_a703f85f.jpg
#   inflating: celebrity/data/Leonardo DiCaprio/091_e39f525d.jpg
#   inflating: __MACOSX/celebrity/data/Leonardo DiCaprio/._091_e39f525d.jpg
#   inflating: celebrity/data/Leonardo DiCaprio/060_668ebb3f.jpg
#   inflating: __MACOSX/celebrity/data/Leonardo DiCaprio/._060_668ebb3f.jpg
#   inflating: celebrity/data/Leonardo DiCaprio/082_d797cdf3.jpg
#   inflating: __MACOSX/celebrity/data/Leonardo DiCaprio/._082_d797cdf3.jpg
#   inflating: celebrity/data/Leonardo DiCaprio/058_0a6c61e9.jpg
#   inflating: __MACOSX/celebrity/data/Leonardo DiCaprio/._058_0a6c61e9.jpg
#   inflating: celebrity/data/Leonardo DiCaprio/006_30010640.jpg
#   inflating: __MACOSX/celebrity/data/Leonardo DiCaprio/._006_30010640.jpg
#   inflating: celebrity/data/Leonardo DiCaprio/029_8522ebc8.jpg
#   inflating: __MACOSX/celebrity/data/Leonardo DiCaprio/._029_8522ebc8.jpg
#   inflating: celebrity/data/Leonardo DiCaprio/022_66e94346.jpg
#   inflating: __MACOSX/celebrity/data/Leonardo DiCaprio/._022_66e94346.jpg
#   inflating: celebrity/data/Leonardo DiCaprio/032_00aee064.jpg
#   inflating: __MACOSX/celebrity/data/Leonardo DiCaprio/._032_00aee064.jpg
#   inflating: celebrity/data/Leonardo DiCaprio/100_ec9fe97f.jpg
#   inflating: __MACOSX/celebrity/data/Leonardo DiCaprio/._100_ec9fe97f.jpg
#   inflating: celebrity/data/Leonardo DiCaprio/050_e7bdecc0.jpg
#   inflating: __MACOSX/celebrity/data/Leonardo DiCaprio/._050_e7bdecc0.jpg
#   inflating: celebrity/data/Leonardo DiCaprio/051_38196d60.jpg
#   inflating: __MACOSX/celebrity/data/Leonardo DiCaprio/._051_38196d60.jpg
#   inflating: celebrity/data/Leonardo DiCaprio/028_38a65d29.jpg
#   inflating: __MACOSX/celebrity/data/Leonardo DiCaprio/._028_38a65d29.jpg
#   inflating: celebrity/data/Leonardo DiCaprio/038_b52784d4.jpg
#   inflating: __MACOSX/celebrity/data/Leonardo DiCaprio/._038_b52784d4.jpg
#   inflating: celebrity/data/Leonardo DiCaprio/052_74c7be90.jpg
#   inflating: __MACOSX/celebrity/data/Leonardo DiCaprio/._052_74c7be90.jpg
#   inflating: celebrity/data/Leonardo DiCaprio/047_ce57f03b.jpg
#   inflating: __MACOSX/celebrity/data/Leonardo DiCaprio/._047_ce57f03b.jpg
#   inflating: celebrity/data/Leonardo DiCaprio/053_8bfac05e.jpg
#   inflating: __MACOSX/celebrity/data/Leonardo DiCaprio/._053_8bfac05e.jpg
#   inflating: celebrity/data/Leonardo DiCaprio/078_a7fd9be1.jpg
#   inflating: __MACOSX/celebrity/data/Leonardo DiCaprio/._078_a7fd9be1.jpg
#   inflating: celebrity/data/Leonardo DiCaprio/079_6ec91919.jpg
#   inflating: __MACOSX/celebrity/data/Leonardo DiCaprio/._079_6ec91919.jpg
#   inflating: celebrity/data/Leonardo DiCaprio/044_f13caf17.jpg
#   inflating: __MACOSX/celebrity/data/Leonardo DiCaprio/._044_f13caf17.jpg
#   inflating: celebrity/data/Leonardo DiCaprio/007_6ca7c622.jpg
#   inflating: __MACOSX/celebrity/data/Leonardo DiCaprio/._007_6ca7c622.jpg
#   inflating: celebrity/data/Leonardo DiCaprio/013_ca6af517.jpg
#   inflating: __MACOSX/celebrity/data/Leonardo DiCaprio/._013_ca6af517.jpg
#   inflating: celebrity/data/Leonardo DiCaprio/092_cbc6d525.jpg
#   inflating: __MACOSX/celebrity/data/Leonardo DiCaprio/._092_cbc6d525.jpg
#   inflating: celebrity/data/Leonardo DiCaprio/087_1382b266.jpg
#   inflating: __MACOSX/celebrity/data/Leonardo DiCaprio/._087_1382b266.jpg
#   inflating: celebrity/data/Leonardo DiCaprio/059_1027f3c2.jpg
#   inflating: __MACOSX/celebrity/data/Leonardo DiCaprio/._059_1027f3c2.jpg
#   inflating: celebrity/data/Leonardo DiCaprio/077_cd8dcf22.jpg
#   inflating: __MACOSX/celebrity/data/Leonardo DiCaprio/._077_cd8dcf22.jpg
#   inflating: celebrity/data/Leonardo DiCaprio/036_f5ea9e84.jpg
#   inflating: __MACOSX/celebrity/data/Leonardo DiCaprio/._036_f5ea9e84.jpg
#   inflating: celebrity/data/Leonardo DiCaprio/073_42e32f65.jpg
#   inflating: __MACOSX/celebrity/data/Leonardo DiCaprio/._073_42e32f65.jpg
#   inflating: celebrity/data/Leonardo DiCaprio/037_fe4d2d8f.jpg
#   inflating: __MACOSX/celebrity/data/Leonardo DiCaprio/._037_fe4d2d8f.jpg
#   inflating: celebrity/data/Leonardo DiCaprio/099_c25b7b04.jpg
#   inflating: __MACOSX/celebrity/data/Leonardo DiCaprio/._099_c25b7b04.jpg
#   inflating: celebrity/data/Leonardo DiCaprio/094_78e0fb7b.jpg
#   inflating: __MACOSX/celebrity/data/Leonardo DiCaprio/._094_78e0fb7b.jpg
#   inflating: celebrity/data/Leonardo DiCaprio/069_b5219746.jpg
#   inflating: __MACOSX/celebrity/data/Leonardo DiCaprio/._069_b5219746.jpg
#   inflating: celebrity/data/Leonardo DiCaprio/010_2f9c83bc.jpg
#   inflating: __MACOSX/celebrity/data/Leonardo DiCaprio/._010_2f9c83bc.jpg
#   inflating: celebrity/data/Leonardo DiCaprio/043_93a5e582.jpg
#   inflating: __MACOSX/celebrity/data/Leonardo DiCaprio/._043_93a5e582.jpg
#   inflating: celebrity/data/Leonardo DiCaprio/021_eecdee92.jpg
#   inflating: __MACOSX/celebrity/data/Leonardo DiCaprio/._021_eecdee92.jpg
#   inflating: celebrity/data/Leonardo DiCaprio/011_0549f94d.jpg
#   inflating: __MACOSX/celebrity/data/Leonardo DiCaprio/._011_0549f94d.jpg
#   inflating: celebrity/data/Leonardo DiCaprio/003_85990366.jpg
#   inflating: __MACOSX/celebrity/data/Leonardo DiCaprio/._003_85990366.jpg
#   inflating: celebrity/data/Leonardo DiCaprio/020_14f28bc8.jpg
#   inflating: __MACOSX/celebrity/data/Leonardo DiCaprio/._020_14f28bc8.jpg
#   inflating: celebrity/data/Leonardo DiCaprio/016_7b57be6a.jpg
#   inflating: __MACOSX/celebrity/data/Leonardo DiCaprio/._016_7b57be6a.jpg
#   inflating: celebrity/data/Leonardo DiCaprio/030_60acb78e.jpg
#   inflating: __MACOSX/celebrity/data/Leonardo DiCaprio/._030_60acb78e.jpg
#   inflating: celebrity/data/Leonardo DiCaprio/039_d49e8191.jpg
#   inflating: __MACOSX/celebrity/data/Leonardo DiCaprio/._039_d49e8191.jpg
#   inflating: celebrity/data/Leonardo DiCaprio/090_b316be20.jpg
#   inflating: __MACOSX/celebrity/data/Leonardo DiCaprio/._090_b316be20.jpg
#   inflating: celebrity/data/Leonardo DiCaprio/076_6fca3a0c.jpg
#   inflating: __MACOSX/celebrity/data/Leonardo DiCaprio/._076_6fca3a0c.jpg
#   inflating: celebrity/data/Leonardo DiCaprio/048_f82caaae.jpg
#   inflating: __MACOSX/celebrity/data/Leonardo DiCaprio/._048_f82caaae.jpg
#   inflating: celebrity/data/Leonardo DiCaprio/008_35daa4bc.jpg
#   inflating: __MACOSX/celebrity/data/Leonardo DiCaprio/._008_35daa4bc.jpg
#   inflating: celebrity/data/Leonardo DiCaprio/009_b86449f6.jpg
#   inflating: __MACOSX/celebrity/data/Leonardo DiCaprio/._009_b86449f6.jpg
#   inflating: celebrity/data/Leonardo DiCaprio/062_67f50ec4.jpg
#   inflating: __MACOSX/celebrity/data/Leonardo DiCaprio/._062_67f50ec4.jpg
#   inflating: celebrity/data/Leonardo DiCaprio/025_e5920270.jpg
#   inflating: __MACOSX/celebrity/data/Leonardo DiCaprio/._025_e5920270.jpg
#   inflating: celebrity/data/Leonardo DiCaprio/041_c91b0923.jpg
#   inflating: __MACOSX/celebrity/data/Leonardo DiCaprio/._041_c91b0923.jpg
#   inflating: celebrity/data/Leonardo DiCaprio/034_00c6d43e.jpg
#   inflating: __MACOSX/celebrity/data/Leonardo DiCaprio/._034_00c6d43e.jpg
#   inflating: celebrity/data/Leonardo DiCaprio/098_f0bc37c7.jpg
#   inflating: __MACOSX/celebrity/data/Leonardo DiCaprio/._098_f0bc37c7.jpg
#   inflating: celebrity/data/Leonardo DiCaprio/040_3a2c98cd.jpg
#   inflating: __MACOSX/celebrity/data/Leonardo DiCaprio/._040_3a2c98cd.jpg
#   inflating: celebrity/data/Leonardo DiCaprio/063_55002ecd.jpg
#   inflating: __MACOSX/celebrity/data/Leonardo DiCaprio/._063_55002ecd.jpg
#   inflating: celebrity/data/Leonardo DiCaprio/014_539eee38.jpg
#   inflating: __MACOSX/celebrity/data/Leonardo DiCaprio/._014_539eee38.jpg
#   inflating: celebrity/data/Leonardo DiCaprio/072_c887ec5c.jpg
#   inflating: __MACOSX/celebrity/data/Leonardo DiCaprio/._072_c887ec5c.jpg
#   inflating: celebrity/data/Leonardo DiCaprio/093_811dc474.jpg
#   inflating: __MACOSX/celebrity/data/Leonardo DiCaprio/._093_811dc474.jpg
#   inflating: celebrity/data/Leonardo DiCaprio/054_1de20f77.jpg
#   inflating: __MACOSX/celebrity/data/Leonardo DiCaprio/._054_1de20f77.jpg
#   inflating: celebrity/data/Leonardo DiCaprio/031_28a211fc.jpg
#   inflating: __MACOSX/celebrity/data/Leonardo DiCaprio/._031_28a211fc.jpg
#   inflating: celebrity/data/Leonardo DiCaprio/086_a1441427.jpg
#   inflating: __MACOSX/celebrity/data/Leonardo DiCaprio/._086_a1441427.jpg
#   inflating: celebrity/data/Leonardo DiCaprio/027_7094e195.jpg
#   inflating: __MACOSX/celebrity/data/Leonardo DiCaprio/._027_7094e195.jpg
#   inflating: celebrity/data/Leonardo DiCaprio/081_a32678db.jpg
#   inflating: __MACOSX/celebrity/data/Leonardo DiCaprio/._081_a32678db.jpg
#   inflating: celebrity/data/Leonardo DiCaprio/045_d074e61c.jpg
#   inflating: __MACOSX/celebrity/data/Leonardo DiCaprio/._045_d074e61c.jpg
#   inflating: celebrity/data/Leonardo DiCaprio/049_37f969c1.jpg
#   inflating: __MACOSX/celebrity/data/Leonardo DiCaprio/._049_37f969c1.jpg
#   inflating: celebrity/data/Leonardo DiCaprio/019_78627223.jpg
#   inflating: __MACOSX/celebrity/data/Leonardo DiCaprio/._019_78627223.jpg
#   inflating: celebrity/data/Leonardo DiCaprio/023_0367d72c.jpg
#   inflating: __MACOSX/celebrity/data/Leonardo DiCaprio/._023_0367d72c.jpg
#   inflating: celebrity/data/Leonardo DiCaprio/070_ae3a4fa0.jpg
#   inflating: __MACOSX/celebrity/data/Leonardo DiCaprio/._070_ae3a4fa0.jpg
#   inflating: celebrity/data/Leonardo DiCaprio/088_41213f8b.jpg
#   inflating: __MACOSX/celebrity/data/Leonardo DiCaprio/._088_41213f8b.jpg
#   inflating: celebrity/data/Leonardo DiCaprio/042_bfbfd7d8.jpg
#   inflating: __MACOSX/celebrity/data/Leonardo DiCaprio/._042_bfbfd7d8.jpg
#   inflating: celebrity/data/Leonardo DiCaprio/075_c2c28553.jpg
#   inflating: __MACOSX/celebrity/data/Leonardo DiCaprio/._075_c2c28553.jpg
#   inflating: celebrity/data/Leonardo DiCaprio/002_86e8aa58.jpg
#   inflating: __MACOSX/celebrity/data/Leonardo DiCaprio/._002_86e8aa58.jpg
#   inflating: celebrity/data/Leonardo DiCaprio/083_f80d8a01.jpg
#   inflating: __MACOSX/celebrity/data/Leonardo DiCaprio/._083_f80d8a01.jpg
#   inflating: celebrity/data/Leonardo DiCaprio/067_a0efbd88.jpg
#   inflating: __MACOSX/celebrity/data/Leonardo DiCaprio/._067_a0efbd88.jpg
#   inflating: celebrity/data/Leonardo DiCaprio/096_c30a9446.jpg
#   inflating: __MACOSX/celebrity/data/Leonardo DiCaprio/._096_c30a9446.jpg
#   inflating: celebrity/data/Leonardo DiCaprio/033_312ea9ed.jpg
#   inflating: __MACOSX/celebrity/data/Leonardo DiCaprio/._033_312ea9ed.jpg
#   inflating: celebrity/data/Leonardo DiCaprio/065_e739f721.jpg
#   inflating: __MACOSX/celebrity/data/Leonardo DiCaprio/._065_e739f721.jpg
#   inflating: celebrity/data/Leonardo DiCaprio/035_ab7cf1c4.jpg
#   inflating: __MACOSX/celebrity/data/Leonardo DiCaprio/._035_ab7cf1c4.jpg
#   inflating: celebrity/data/Jennifer Lawrence/044_2619e688.jpg
#   inflating: __MACOSX/celebrity/data/Jennifer Lawrence/._044_2619e688.jpg
#   inflating: celebrity/data/Jennifer Lawrence/035_39bf8fcb.jpg
#   inflating: __MACOSX/celebrity/data/Jennifer Lawrence/._035_39bf8fcb.jpg
#   inflating: celebrity/data/Jennifer Lawrence/060_bb963eed.jpg
#   inflating: __MACOSX/celebrity/data/Jennifer Lawrence/._060_bb963eed.jpg
#   inflating: celebrity/data/Jennifer Lawrence/018_2974b20a.jpg
#   inflating: __MACOSX/celebrity/data/Jennifer Lawrence/._018_2974b20a.jpg
#   inflating: celebrity/data/Jennifer Lawrence/064_3e07b8f6.jpg
#   inflating: __MACOSX/celebrity/data/Jennifer Lawrence/._064_3e07b8f6.jpg
#   inflating: celebrity/data/Jennifer Lawrence/095_0ccffcb8.jpg
#   inflating: __MACOSX/celebrity/data/Jennifer Lawrence/._095_0ccffcb8.jpg
#   inflating: celebrity/data/Jennifer Lawrence/056_f22ab393.jpg
#   inflating: __MACOSX/celebrity/data/Jennifer Lawrence/._056_f22ab393.jpg
#   inflating: celebrity/data/Jennifer Lawrence/084_0f0f27e4.jpg
#   inflating: __MACOSX/celebrity/data/Jennifer Lawrence/._084_0f0f27e4.jpg
#   inflating: celebrity/data/Jennifer Lawrence/042_db56b563.jpg
#   inflating: __MACOSX/celebrity/data/Jennifer Lawrence/._042_db56b563.jpg
#   inflating: celebrity/data/Jennifer Lawrence/094_c0a66044.jpg
#   inflating: __MACOSX/celebrity/data/Jennifer Lawrence/._094_c0a66044.jpg
#   inflating: celebrity/data/Jennifer Lawrence/071_70e7bd88.jpg
#   inflating: __MACOSX/celebrity/data/Jennifer Lawrence/._071_70e7bd88.jpg
#   inflating: celebrity/data/Jennifer Lawrence/066_4c979163.jpg
#   inflating: __MACOSX/celebrity/data/Jennifer Lawrence/._066_4c979163.jpg
#   inflating: celebrity/data/Jennifer Lawrence/091_e8f3497f.jpg
#   inflating: __MACOSX/celebrity/data/Jennifer Lawrence/._091_e8f3497f.jpg
#   inflating: celebrity/data/Jennifer Lawrence/063_67d7dfda.jpg
#   inflating: __MACOSX/celebrity/data/Jennifer Lawrence/._063_67d7dfda.jpg
#   inflating: celebrity/data/Jennifer Lawrence/092_aebdc10e.jpg
#   inflating: __MACOSX/celebrity/data/Jennifer Lawrence/._092_aebdc10e.jpg
#   inflating: celebrity/data/Jennifer Lawrence/036_e76dcff2.jpg
#   inflating: __MACOSX/celebrity/data/Jennifer Lawrence/._036_e76dcff2.jpg
#   inflating: celebrity/data/Jennifer Lawrence/002_533748b2.jpg
#   inflating: __MACOSX/celebrity/data/Jennifer Lawrence/._002_533748b2.jpg
#   inflating: celebrity/data/Jennifer Lawrence/059_dd54feaf.jpg
#   inflating: __MACOSX/celebrity/data/Jennifer Lawrence/._059_dd54feaf.jpg
#   inflating: celebrity/data/Jennifer Lawrence/024_bfe8d1d4.jpg
#   inflating: __MACOSX/celebrity/data/Jennifer Lawrence/._024_bfe8d1d4.jpg
#   inflating: celebrity/data/Jennifer Lawrence/040_b392a367.jpg
#   inflating: __MACOSX/celebrity/data/Jennifer Lawrence/._040_b392a367.jpg
#   inflating: celebrity/data/Jennifer Lawrence/054_cc2a9231.jpg
#   inflating: __MACOSX/celebrity/data/Jennifer Lawrence/._054_cc2a9231.jpg
#   inflating: celebrity/data/Jennifer Lawrence/031_0785344e.jpg
#   inflating: __MACOSX/celebrity/data/Jennifer Lawrence/._031_0785344e.jpg
#   inflating: celebrity/data/Jennifer Lawrence/058_a8b460e9.jpg
#   inflating: __MACOSX/celebrity/data/Jennifer Lawrence/._058_a8b460e9.jpg
#   inflating: celebrity/data/Jennifer Lawrence/029_7cc8d551.jpg
#   inflating: __MACOSX/celebrity/data/Jennifer Lawrence/._029_7cc8d551.jpg
#   inflating: celebrity/data/Jennifer Lawrence/034_de792370.jpg
#   inflating: __MACOSX/celebrity/data/Jennifer Lawrence/._034_de792370.jpg
#   inflating: celebrity/data/Jennifer Lawrence/019_ab6f69c3.jpg
#   inflating: __MACOSX/celebrity/data/Jennifer Lawrence/._019_ab6f69c3.jpg
#   inflating: celebrity/data/Jennifer Lawrence/085_b2827d47.jpg
#   inflating: __MACOSX/celebrity/data/Jennifer Lawrence/._085_b2827d47.jpg
#   inflating: celebrity/data/Jennifer Lawrence/013_78060c8a.jpg
#   inflating: __MACOSX/celebrity/data/Jennifer Lawrence/._013_78060c8a.jpg
#   inflating: celebrity/data/Jennifer Lawrence/051_2aace444.jpg
#   inflating: __MACOSX/celebrity/data/Jennifer Lawrence/._051_2aace444.jpg
#   inflating: celebrity/data/Jennifer Lawrence/061_2306ab5b.jpg
#   inflating: __MACOSX/celebrity/data/Jennifer Lawrence/._061_2306ab5b.jpg
#   inflating: celebrity/data/Jennifer Lawrence/097_f19b4cfc.jpg
#   inflating: __MACOSX/celebrity/data/Jennifer Lawrence/._097_f19b4cfc.jpg
#   inflating: celebrity/data/Jennifer Lawrence/033_c27f428c.jpg
#   inflating: __MACOSX/celebrity/data/Jennifer Lawrence/._033_c27f428c.jpg
#   inflating: celebrity/data/Jennifer Lawrence/090_14fe77d5.jpg
#   inflating: __MACOSX/celebrity/data/Jennifer Lawrence/._090_14fe77d5.jpg
#   inflating: celebrity/data/Jennifer Lawrence/017_b67e0915.jpg
#   inflating: __MACOSX/celebrity/data/Jennifer Lawrence/._017_b67e0915.jpg
#   inflating: celebrity/data/Jennifer Lawrence/068_9718f48b.jpg
#   inflating: __MACOSX/celebrity/data/Jennifer Lawrence/._068_9718f48b.jpg
#   inflating: celebrity/data/Jennifer Lawrence/037_46ec39ce.jpg
#   inflating: __MACOSX/celebrity/data/Jennifer Lawrence/._037_46ec39ce.jpg
#   inflating: celebrity/data/Jennifer Lawrence/074_ed2be25f.jpg
#   inflating: __MACOSX/celebrity/data/Jennifer Lawrence/._074_ed2be25f.jpg
#   inflating: celebrity/data/Jennifer Lawrence/032_bed86546.jpg
#   inflating: __MACOSX/celebrity/data/Jennifer Lawrence/._032_bed86546.jpg
# ...
#   inflating: __MACOSX/celebrity/data/Sandra Bullock/._064_84cdff70.jpg
#   inflating: celebrity/data/Sandra Bullock/025_d5418b1e.jpg
#   inflating: __MACOSX/celebrity/data/Sandra Bullock/._025_d5418b1e.jpg
#   inflating: celebrity/data/Sandra Bullock/041_642b1b15.jpg
#   inflating: __MACOSX/celebrity/data/Sandra Bullock/._041_642b1b15.jpg
#   inflating: celebrity/data/Sandra Bullock/028_5388c983.jpg
#   inflating: __MACOSX/celebrity/data/Sandra Bullock/._028_5388c983.jpg
#   inflating: celebrity/data/Sandra Bullock/099_d22b8b8b.jpg
#   inflating: __MACOSX/celebrity/data/Sandra Bullock/._099_d22b8b8b.jpg
#   inflating: celebrity/data/Sandra Bullock/096_4eb6b8b7.jpg
#   inflating: __MACOSX/celebrity/data/Sandra Bullock/._096_4eb6b8b7.jpg
#   inflating: celebrity/data/Sandra Bullock/027_f5294957.jpg
#   inflating: __MACOSX/celebrity/data/Sandra Bullock/._027_f5294957.jpg
#   inflating: celebrity/data/Sandra Bullock/003_0e3303fc.jpg
#   inflating: __MACOSX/celebrity/data/Sandra Bullock/._003_0e3303fc.jpg
#   inflating: celebrity/data/Sandra Bullock/023_7214d0b2.jpg
#   inflating: __MACOSX/celebrity/data/Sandra Bullock/._023_7214d0b2.jpg
#   inflating: celebrity/data/Sandra Bullock/011_96913041.jpg
#   inflating: __MACOSX/celebrity/data/Sandra Bullock/._011_96913041.jpg
#   inflating: celebrity/data/Sandra Bullock/061_694af034.jpg
#   inflating: __MACOSX/celebrity/data/Sandra Bullock/._061_694af034.jpg
#   inflating: celebrity/data/Sandra Bullock/068_4b87f13b.jpg
#   inflating: __MACOSX/celebrity/data/Sandra Bullock/._068_4b87f13b.jpg
#   inflating: celebrity/data/Sandra Bullock/043_4f352240.jpg
#   inflating: __MACOSX/celebrity/data/Sandra Bullock/._043_4f352240.jpg
#   inflating: celebrity/data/Sandra Bullock/091_37b0b664.jpg
#   inflating: __MACOSX/celebrity/data/Sandra Bullock/._091_37b0b664.jpg
#   inflating: celebrity/data/Sandra Bullock/090_f3644e6b.jpg
#   inflating: __MACOSX/celebrity/data/Sandra Bullock/._090_f3644e6b.jpg
#   inflating: celebrity/data/Sandra Bullock/009_41aa3ed9.jpg
#   inflating: __MACOSX/celebrity/data/Sandra Bullock/._009_41aa3ed9.jpg
#   inflating: celebrity/data/Sandra Bullock/032_f3773aa6.jpg
#   inflating: __MACOSX/celebrity/data/Sandra Bullock/._032_f3773aa6.jpg
#   inflating: celebrity/data/Sandra Bullock/085_69f8d759.jpg
#   inflating: __MACOSX/celebrity/data/Sandra Bullock/._085_69f8d759.jpg
#   inflating: celebrity/data/Sandra Bullock/080_abc596b4.jpg
#   inflating: __MACOSX/celebrity/data/Sandra Bullock/._080_abc596b4.jpg
#   inflating: celebrity/data/Sandra Bullock/075_4b6e8283.jpg
#   inflating: __MACOSX/celebrity/data/Sandra Bullock/._075_4b6e8283.jpg
#   inflating: celebrity/data/Sandra Bullock/040_4b9bc437.jpg
#   inflating: __MACOSX/celebrity/data/Sandra Bullock/._040_4b9bc437.jpg
#   inflating: celebrity/data/Sandra Bullock/077_d8ba3326.jpg
#   inflating: __MACOSX/celebrity/data/Sandra Bullock/._077_d8ba3326.jpg
#   inflating: celebrity/data/Sandra Bullock/021_7ae7b9a5.jpg
#   inflating: __MACOSX/celebrity/data/Sandra Bullock/._021_7ae7b9a5.jpg
#   inflating: celebrity/data/Sandra Bullock/029_c1a6907a.jpg
#   inflating: __MACOSX/celebrity/data/Sandra Bullock/._029_c1a6907a.jpg
#   inflating: celebrity/data/Sandra Bullock/039_7654fd34.jpg
#   inflating: __MACOSX/celebrity/data/Sandra Bullock/._039_7654fd34.jpg
#   inflating: celebrity/data/Sandra Bullock/033_bc82f2a9.jpg
#   inflating: __MACOSX/celebrity/data/Sandra Bullock/._033_bc82f2a9.jpg
#   inflating: celebrity/data/Megan Fox/081_f78b8266.jpg
#   inflating: __MACOSX/celebrity/data/Megan Fox/._081_f78b8266.jpg
#   inflating: celebrity/data/Megan Fox/061_d844ec74.jpg
#   inflating: __MACOSX/celebrity/data/Megan Fox/._061_d844ec74.jpg
#   inflating: celebrity/data/Megan Fox/051_d62b71ee.jpg
#   inflating: __MACOSX/celebrity/data/Megan Fox/._051_d62b71ee.jpg
#   inflating: celebrity/data/Megan Fox/038_fe7a12d1.jpg
#   inflating: __MACOSX/celebrity/data/Megan Fox/._038_fe7a12d1.jpg
#   inflating: celebrity/data/Megan Fox/052_3f3b6764.jpg
#   inflating: __MACOSX/celebrity/data/Megan Fox/._052_3f3b6764.jpg
#   inflating: celebrity/data/Megan Fox/083_323ae1e8.jpg
#   inflating: __MACOSX/celebrity/data/Megan Fox/._083_323ae1e8.jpg
#   inflating: celebrity/data/Megan Fox/033_4e5edeac.jpg
#   inflating: __MACOSX/celebrity/data/Megan Fox/._033_4e5edeac.jpg
#   inflating: celebrity/data/Megan Fox/057_d2d179a5.jpg
#   inflating: __MACOSX/celebrity/data/Megan Fox/._057_d2d179a5.jpg
#   inflating: celebrity/data/Megan Fox/071_d75194ff.jpg
#   inflating: __MACOSX/celebrity/data/Megan Fox/._071_d75194ff.jpg
#   inflating: celebrity/data/Megan Fox/097_e1dabc00.jpg
#   inflating: __MACOSX/celebrity/data/Megan Fox/._097_e1dabc00.jpg
#   inflating: celebrity/data/Megan Fox/044_bad2076f.jpg
#   inflating: __MACOSX/celebrity/data/Megan Fox/._044_bad2076f.jpg
#   inflating: celebrity/data/Megan Fox/070_4de04405.jpg
#   inflating: __MACOSX/celebrity/data/Megan Fox/._070_4de04405.jpg
#   inflating: celebrity/data/Megan Fox/090_a2269658.jpg
#   inflating: __MACOSX/celebrity/data/Megan Fox/._090_a2269658.jpg
#   inflating: celebrity/data/Megan Fox/024_2c2a7324.jpg
#   inflating: __MACOSX/celebrity/data/Megan Fox/._024_2c2a7324.jpg
#   inflating: celebrity/data/Megan Fox/013_f4968d00.jpg
#   inflating: __MACOSX/celebrity/data/Megan Fox/._013_f4968d00.jpg
#   inflating: celebrity/data/Megan Fox/079_4e33cd00.jpg
#   inflating: __MACOSX/celebrity/data/Megan Fox/._079_4e33cd00.jpg
#   inflating: celebrity/data/Megan Fox/047_3043a87c.jpg
#   inflating: __MACOSX/celebrity/data/Megan Fox/._047_3043a87c.jpg
#   inflating: celebrity/data/Megan Fox/046_953d292e.jpg
#   inflating: __MACOSX/celebrity/data/Megan Fox/._046_953d292e.jpg
#   inflating: celebrity/data/Megan Fox/045_22823571.jpg
#   inflating: __MACOSX/celebrity/data/Megan Fox/._045_22823571.jpg
#   inflating: celebrity/data/Megan Fox/100_f0e45dd1.jpg
#   inflating: __MACOSX/celebrity/data/Megan Fox/._100_f0e45dd1.jpg
#   inflating: celebrity/data/Megan Fox/027_308c9885.jpg
#   inflating: __MACOSX/celebrity/data/Megan Fox/._027_308c9885.jpg
#   inflating: celebrity/data/Megan Fox/056_ce828b1f.jpg
#   inflating: __MACOSX/celebrity/data/Megan Fox/._056_ce828b1f.jpg
#   inflating: celebrity/data/Megan Fox/065_016dc8e2.jpg
#   inflating: __MACOSX/celebrity/data/Megan Fox/._065_016dc8e2.jpg
#   inflating: celebrity/data/Megan Fox/082_768aecdd.jpg
#   inflating: __MACOSX/celebrity/data/Megan Fox/._082_768aecdd.jpg
#   inflating: celebrity/data/Megan Fox/055_9508128d.jpg
#   inflating: __MACOSX/celebrity/data/Megan Fox/._055_9508128d.jpg
#   inflating: celebrity/data/Megan Fox/053_6ad198c0.jpg
#   inflating: __MACOSX/celebrity/data/Megan Fox/._053_6ad198c0.jpg
#   inflating: celebrity/data/Megan Fox/003_61dd1e53.jpg
#   inflating: __MACOSX/celebrity/data/Megan Fox/._003_61dd1e53.jpg
#   inflating: celebrity/data/Megan Fox/010_0479e335.jpg
#   inflating: __MACOSX/celebrity/data/Megan Fox/._010_0479e335.jpg
#   inflating: celebrity/data/Megan Fox/059_d09c7676.jpg
#   inflating: __MACOSX/celebrity/data/Megan Fox/._059_d09c7676.jpg
#   inflating: celebrity/data/Megan Fox/022_784eea3c.jpg
#   inflating: __MACOSX/celebrity/data/Megan Fox/._022_784eea3c.jpg
#   inflating: celebrity/data/Megan Fox/019_8e696057.jpg
#   inflating: __MACOSX/celebrity/data/Megan Fox/._019_8e696057.jpg
#   inflating: celebrity/data/Megan Fox/076_424b03b7.jpg
#   inflating: __MACOSX/celebrity/data/Megan Fox/._076_424b03b7.jpg
#   inflating: celebrity/data/Megan Fox/025_b7dee9f2.jpg
#   inflating: __MACOSX/celebrity/data/Megan Fox/._025_b7dee9f2.jpg
#   inflating: celebrity/data/Megan Fox/063_10c723ae.jpg
#   inflating: __MACOSX/celebrity/data/Megan Fox/._063_10c723ae.jpg
#   inflating: celebrity/data/Megan Fox/029_19296e1d.jpg
#   inflating: __MACOSX/celebrity/data/Megan Fox/._029_19296e1d.jpg
#   inflating: celebrity/data/Megan Fox/005_9574c208.jpg
#   inflating: __MACOSX/celebrity/data/Megan Fox/._005_9574c208.jpg
#   inflating: celebrity/data/Megan Fox/006_4e33c943.jpg
#   inflating: __MACOSX/celebrity/data/Megan Fox/._006_4e33c943.jpg
#   inflating: celebrity/data/Megan Fox/039_45475171.jpg
#   inflating: __MACOSX/celebrity/data/Megan Fox/._039_45475171.jpg
#   inflating: celebrity/data/Megan Fox/093_82a4677f.jpg
#   inflating: __MACOSX/celebrity/data/Megan Fox/._093_82a4677f.jpg
#   inflating: celebrity/data/Megan Fox/035_21c88485.jpg
#   inflating: __MACOSX/celebrity/data/Megan Fox/._035_21c88485.jpg
#   inflating: celebrity/data/Megan Fox/088_29b6bf25.jpg
#   inflating: __MACOSX/celebrity/data/Megan Fox/._088_29b6bf25.jpg
#   inflating: celebrity/data/Megan Fox/032_4feb9977.jpg
#   inflating: __MACOSX/celebrity/data/Megan Fox/._032_4feb9977.jpg
#   inflating: celebrity/data/Megan Fox/034_27326b4e.jpg
#   inflating: __MACOSX/celebrity/data/Megan Fox/._034_27326b4e.jpg
#   inflating: celebrity/data/Megan Fox/086_b9831d16.jpg
#   inflating: __MACOSX/celebrity/data/Megan Fox/._086_b9831d16.jpg
#   inflating: celebrity/data/Megan Fox/092_bbd39177.jpg
#   inflating: __MACOSX/celebrity/data/Megan Fox/._092_bbd39177.jpg
#   inflating: celebrity/data/Megan Fox/021_2d9dd3a2.jpg
#   inflating: __MACOSX/celebrity/data/Megan Fox/._021_2d9dd3a2.jpg
#   inflating: celebrity/data/Megan Fox/069_0ffb5c63.jpg
#   inflating: __MACOSX/celebrity/data/Megan Fox/._069_0ffb5c63.jpg
#   inflating: celebrity/data/Megan Fox/031_d719ba67.jpg
#   inflating: __MACOSX/celebrity/data/Megan Fox/._031_d719ba67.jpg
#   inflating: celebrity/data/Megan Fox/085_2a0a4182.jpg
#   inflating: __MACOSX/celebrity/data/Megan Fox/._085_2a0a4182.jpg
#   inflating: celebrity/data/Megan Fox/066_50092138.jpg
#   inflating: __MACOSX/celebrity/data/Megan Fox/._066_50092138.jpg
#   inflating: celebrity/data/Megan Fox/036_e61191e5.jpg
#   inflating: __MACOSX/celebrity/data/Megan Fox/._036_e61191e5.jpg
#   inflating: celebrity/data/Megan Fox/028_44417c0b.jpg
#   inflating: __MACOSX/celebrity/data/Megan Fox/._028_44417c0b.jpg
#   inflating: celebrity/data/Megan Fox/014_d6e920d4.jpg
#   inflating: __MACOSX/celebrity/data/Megan Fox/._014_d6e920d4.jpg
#   inflating: celebrity/data/Megan Fox/048_aae58619.jpg
#   inflating: __MACOSX/celebrity/data/Megan Fox/._048_aae58619.jpg
#   inflating: celebrity/data/Megan Fox/062_2539f58f.jpg
#   inflating: __MACOSX/celebrity/data/Megan Fox/._062_2539f58f.jpg
#   inflating: celebrity/data/Megan Fox/002_6e289116.jpg
#   inflating: __MACOSX/celebrity/data/Megan Fox/._002_6e289116.jpg
#   inflating: celebrity/data/Megan Fox/058_1b5b5422.jpg
#   inflating: __MACOSX/celebrity/data/Megan Fox/._058_1b5b5422.jpg
#   inflating: celebrity/data/Megan Fox/020_467a9bd7.jpg
#   inflating: __MACOSX/celebrity/data/Megan Fox/._020_467a9bd7.jpg
#   inflating: celebrity/data/Megan Fox/008_74bda018.jpg
#   inflating: __MACOSX/celebrity/data/Megan Fox/._008_74bda018.jpg
#   inflating: celebrity/data/Megan Fox/091_4858eb13.jpg
#   inflating: __MACOSX/celebrity/data/Megan Fox/._091_4858eb13.jpg
#   inflating: celebrity/data/Megan Fox/011_b2354fd0.jpg
#   inflating: __MACOSX/celebrity/data/Megan Fox/._011_b2354fd0.jpg
#   inflating: celebrity/data/Megan Fox/016_bd51d057.jpg
#   inflating: __MACOSX/celebrity/data/Megan Fox/._016_bd51d057.jpg
#   inflating: celebrity/data/Megan Fox/037_f01637d6.jpg
#   inflating: __MACOSX/celebrity/data/Megan Fox/._037_f01637d6.jpg
#   inflating: celebrity/data/Megan Fox/004_6aede3d3.jpg
#   inflating: __MACOSX/celebrity/data/Megan Fox/._004_6aede3d3.jpg
#   inflating: celebrity/data/Megan Fox/096_2ca8243d.jpg
#   inflating: __MACOSX/celebrity/data/Megan Fox/._096_2ca8243d.jpg
#   inflating: celebrity/data/Megan Fox/012_d461a2b5.jpg
#   inflating: __MACOSX/celebrity/data/Megan Fox/._012_d461a2b5.jpg
#   inflating: celebrity/data/Megan Fox/078_6af10def.jpg
#   inflating: __MACOSX/celebrity/data/Megan Fox/._078_6af10def.jpg
#   inflating: celebrity/data/Megan Fox/099_82722976.jpg
#   inflating: __MACOSX/celebrity/data/Megan Fox/._099_82722976.jpg
#   inflating: celebrity/data/Megan Fox/030_02e7f231.jpg
#   inflating: __MACOSX/celebrity/data/Megan Fox/._030_02e7f231.jpg
#   inflating: celebrity/data/Megan Fox/060_f5a38fe0.jpg
#   inflating: __MACOSX/celebrity/data/Megan Fox/._060_f5a38fe0.jpg
#   inflating: celebrity/data/Megan Fox/080_bff10b31.jpg
#   inflating: __MACOSX/celebrity/data/Megan Fox/._080_bff10b31.jpg
#   inflating: celebrity/data/Megan Fox/098_24676238.jpg
#   inflating: __MACOSX/celebrity/data/Megan Fox/._098_24676238.jpg
#   inflating: celebrity/data/Megan Fox/084_70354863.jpg
#   inflating: __MACOSX/celebrity/data/Megan Fox/._084_70354863.jpg
#   inflating: celebrity/data/Megan Fox/040_11ad3b6e.jpg
#   inflating: __MACOSX/celebrity/data/Megan Fox/._040_11ad3b6e.jpg
#   inflating: celebrity/data/Megan Fox/072_5debf32c.jpg
#   inflating: __MACOSX/celebrity/data/Megan Fox/._072_5debf32c.jpg
#   inflating: celebrity/data/Megan Fox/015_b4a21d28.jpg
#   inflating: __MACOSX/celebrity/data/Megan Fox/._015_b4a21d28.jpg
#   inflating: celebrity/data/Megan Fox/049_2efe85b0.jpg
#   inflating: __MACOSX/celebrity/data/Megan Fox/._049_2efe85b0.jpg
#   inflating: celebrity/data/Megan Fox/073_b7f93635.jpg
#   inflating: __MACOSX/celebrity/data/Megan Fox/._073_b7f93635.jpg
#   inflating: celebrity/data/Megan Fox/042_870cbd50.jpg
#   inflating: __MACOSX/celebrity/data/Megan Fox/._042_870cbd50.jpg
#   inflating: celebrity/data/Megan Fox/050_b4742a63.jpg
#   inflating: __MACOSX/celebrity/data/Megan Fox/._050_b4742a63.jpg
#   inflating: celebrity/data/Megan Fox/075_9b57684f.jpg
#   inflating: __MACOSX/celebrity/data/Megan Fox/._075_9b57684f.jpg
#   inflating: celebrity/data/Megan Fox/054_5a9566eb.jpg
#   inflating: __MACOSX/celebrity/data/Megan Fox/._054_5a9566eb.jpg
#   inflating: celebrity/data/Megan Fox/001_dfb62d96.jpg
#   inflating: __MACOSX/celebrity/data/Megan Fox/._001_dfb62d96.jpg
#   inflating: celebrity/data/Megan Fox/026_9ebf29ab.jpg
#   inflating: __MACOSX/celebrity/data/Megan Fox/._026_9ebf29ab.jpg
#   inflating: celebrity/data/Megan Fox/064_61385762.jpg
#   inflating: __MACOSX/celebrity/data/Megan Fox/._064_61385762.jpg
#   inflating: celebrity/data/Megan Fox/089_ae8644ab.jpg
#   inflating: __MACOSX/celebrity/data/Megan Fox/._089_ae8644ab.jpg
#   inflating: celebrity/data/Megan Fox/068_b8b844e2.jpg
#   inflating: __MACOSX/celebrity/data/Megan Fox/._068_b8b844e2.jpg
#   inflating: celebrity/data/Megan Fox/007_e3073d58.jpg
#   inflating: __MACOSX/celebrity/data/Megan Fox/._007_e3073d58.jpg
#   inflating: celebrity/data/Megan Fox/067_4017d5e9.jpg
#   inflating: __MACOSX/celebrity/data/Megan Fox/._067_4017d5e9.jpg
#   inflating: celebrity/data/Megan Fox/094_1095eeb6.jpg
#   inflating: __MACOSX/celebrity/data/Megan Fox/._094_1095eeb6.jpg
#   inflating: celebrity/data/Megan Fox/077_de6b59a7.jpg
#   inflating: __MACOSX/celebrity/data/Megan Fox/._077_de6b59a7.jpg
#   inflating: celebrity/data/Megan Fox/017_eed36648.jpg
#   inflating: __MACOSX/celebrity/data/Megan Fox/._017_eed36648.jpg
#   inflating: celebrity/data/Megan Fox/074_59a9ebff.jpg
#   inflating: __MACOSX/celebrity/data/Megan Fox/._074_59a9ebff.jpg
#   inflating: celebrity/data/Megan Fox/043_8ab0e1e6.jpg
#   inflating: __MACOSX/celebrity/data/Megan Fox/._043_8ab0e1e6.jpg
#   inflating: celebrity/data/Megan Fox/087_90c1dd76.jpg
#   inflating: __MACOSX/celebrity/data/Megan Fox/._087_90c1dd76.jpg
#   inflating: celebrity/data/Megan Fox/095_fc25a60b.jpg
#   inflating: __MACOSX/celebrity/data/Megan Fox/._095_fc25a60b.jpg
#   inflating: celebrity/data/Megan Fox/009_3283c30e.jpg
#   inflating: __MACOSX/celebrity/data/Megan Fox/._009_3283c30e.jpg
#   inflating: celebrity/data/Megan Fox/018_394cfad7.jpg
#   inflating: __MACOSX/celebrity/data/Megan Fox/._018_394cfad7.jpg
#   inflating: celebrity/data/Megan Fox/023_55dd20e3.jpg
#   inflating: __MACOSX/celebrity/data/Megan Fox/._023_55dd20e3.jpg
#   inflating: celebrity/data/Megan Fox/041_139bb2a5.jpg
#   inflating: __MACOSX/celebrity/data/Megan Fox/._041_139bb2a5.jpg
# celebrity  celebrity.zip  __MACOSX

# %%
root = 'celebrity/data'
#exclude = ['BACKGROUND_Google', 'Motorbikes', 'airplanes', 'Faces_easy', 'Faces']
exclude = []
train_split, val_split = 0.7, 0.15

categories = [x[0] for x in os.walk(root) if x[0]][1:]
categories = [c for c in categories if c not in [os.path.join(root, e) for e in exclude]]

print(categories)
# Out:
# ['celebrity/data/Sandra Bullock', 'celebrity/data/Will Smith', 'celebrity/data/Natalie Portman', 'celebrity/data/Hugh Jackman', 'celebrity/data/Robert Downey Jr', 'celebrity/data/Denzel Washington', 'celebrity/data/Megan Fox', 'celebrity/data/Scarlett Johansson', 'celebrity/data/Tom Cruise', 'celebrity/data/Kate Winslet', 'celebrity/data/Angelina Jolie', 'celebrity/data/Brad Pitt', 'celebrity/data/Nicole Kidman', 'celebrity/data/Tom Hanks', 'celebrity/data/Johnny Depp', 'celebrity/data/Leonardo DiCaprio', 'celebrity/data/Jennifer Lawrence']

# %% [markdown]
# This function is useful for pre-processing the data into an image and input vector.

# %%
from PIL import Image

# helper function to load image and return it and input vector
def get_image(path):
    try:
        img = Image.open(path)
        img = img.convert('RGB')
        x = np.array(img.resize((224, 224)))
        x = np.expand_dims(x, axis=0)
        x = preprocess_input(x)
        return img, x
    except Exception as e:
        print(f"Error loading image: {path}")
        return None, None

# %% [markdown]
# Load all the images from root folder

# %%
data = []
for c, category in enumerate(categories):
    images = [os.path.join(dp, f) for dp, dn, filenames
              in os.walk(category) for f in filenames
              if os.path.splitext(f)[1].lower() in ['.jpg','.png','.jpeg']]
    for img_path in images:
        img, x = get_image(img_path)
        if x is not None:
          data.append({'x':np.array(x[0]), 'y':c})

# count the number of classes
num_classes = len(categories)

# %% [markdown]
# Randomize the data order.

# %%
random.shuffle(data)

# %% [markdown]
# create training / validation / test split (70%, 15%, 15%)

# %%
idx_val = int(train_split * len(data))
idx_test = int((train_split + val_split) * len(data))
train = data[:idx_val]
val = data[idx_val:idx_test]
test = data[idx_test:]

# %% [markdown]
# Separate data for labels.

# %%
x_train, y_train = np.array([t["x"] for t in train]), [t["y"] for t in train]
x_val, y_val = np.array([t["x"] for t in val]), [t["y"] for t in val]
x_test, y_test = np.array([t["x"] for t in test]), [t["y"] for t in test]
print(y_test)
# Out:
# [16, 5, 7, 5, 13, 15, 3, 7, 0, 7, 12, 1, 8, 9, 9, 4, 4, 11, 6, 0, 12, 16, 4, 7, 12, 5, 15, 15, 12, 8, 7, 7, 3, 13, 3, 8, 16, 7, 3, 0, 7, 2, 1, 12, 1, 13, 11, 13, 9, 9, 10, 4, 1, 7, 5, 7, 7, 6, 4, 5, 1, 16, 6, 12, 9, 1, 8, 2, 0, 8, 5, 5, 7, 12, 4, 5, 8, 6, 4, 2, 5, 15, 14, 13, 6, 11, 2, 1, 1, 7, 12, 15, 1, 8, 13, 7, 8, 2, 5, 7, 12, 13, 14, 1, 9, 11, 9, 7, 8, 15, 0, 7, 13, 11, 7, 10, 2, 0, 11, 4, 2, 5, 10, 9, 8, 5, 3, 2, 1, 7, 7, 11, 12, 13, 13, 14, 16, 0, 14, 1, 2, 13, 16, 4, 6, 0, 4, 16, 16, 7, 0, 15, 4, 7, 0, 15, 15, 5, 4, 7, 9, 6, 10, 6, 5, 9, 0, 7, 10, 2, 7, 4, 16, 9, 13, 13, 7, 14, 14, 9, 6, 9, 14, 7, 10, 2, 3, 6, 1, 1, 2, 10, 7, 5, 12, 4, 7, 10, 12, 14, 12, 14, 7, 6, 12, 9, 0, 6, 12, 7, 4, 13, 7, 4, 11, 2, 9, 16, 7, 15, 12, 9, 7, 10, 15, 0, 16, 11, 6, 10, 9, 0, 11, 14, 16, 6, 2, 3, 1, 8, 2, 2, 2, 3, 2, 5, 7, 10, 11, 14, 10, 2, 15, 4, 10, 3, 9, 12, 15, 14, 11, 7, 3, 0, 8, 10, 6, 12, 10, 12]

# %% [markdown]
# Pre-process the data as before by making sure it's float32 and normalized between 0 and 1.

# %%
# normalize data
x_train = x_train.astype('float32') / 255.
x_val = x_val.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.

# convert labels to one-hot vectors
y_train = keras.utils.to_categorical(y_train, num_classes)
y_val = keras.utils.to_categorical(y_val, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)
print(y_test.shape)
# Out:
# (270, 17)

# %% [markdown]
# Let's get a summary of what we have.

# %%
# summary
print("finished loading %d images from %d categories"%(len(data), num_classes))
print("train / validation / test split: %d, %d, %d"%(len(x_train), len(x_val), len(x_test)))
print("training data shape: ", x_train.shape)
print("training labels shape: ", y_train.shape)
# Out:
# finished loading 1800 images from 17 categories
# train / validation / test split: 1260, 270, 270
# training data shape:  (1260, 224, 224, 3)
# training labels shape:  (1260, 17)

# %% [markdown]
# If everything worked properly, you should have loaded a bunch of images, and split them into three sets: `train`, `val`, and `test`. The shape of the training data should be (`n`, 224, 224, 3) where `n` is the size of your training set, and the labels should be (`n`, `c`) where `c` is the number of classes (97 in the case of `101_ObjectCategories`.
#
# Notice that we divided all the data into three subsets -- a training set `train`, a validation set `val`, and a test set `test`. The reason for this is to properly evaluate the accuracy of our classifier. During training, the optimizer uses the validation set to evaluate its internal performance, in order to determine the gradient without overfitting to the training set. The `test` set is always held out from the training algorithm, and is only used at the end to evaluate the final accuracy of our model.
#
# Let's quickly look at a few sample images from our dataset.

# %%
images = [os.path.join(dp, f) for dp, dn, filenames in os.walk(root) for f in filenames if os.path.splitext(f)[1].lower() in ['.jpg','.png','.jpeg']]
idx = [int(len(images) * random.random()) for i in range(8)]
imgs = [image.load_img(images[i], target_size=(224, 224)) for i in idx]
concat_image = np.concatenate([np.asarray(img) for img in imgs], axis=1)
plt.figure(figsize=(16,4))
plt.imshow(concat_image)

# %% [markdown]
# ### First training a neural net from scratch
#
# Before doing the transfer learning, let's first build a neural network from scratch for doing classification on our dataset. This will give us a baseline to compare to our transfer-learned network later.
#
# The network we will construct contains 4 alternating convolutional and max-pooling layers, followed by a [dropout](https://www.cs.toronto.edu/~hinton/absps/JMLRdropout.pdf) after every other conv/pooling pair. After the last pooling layer, we will attach a fully-connected layer with 256 neurons, another dropout layer, then finally a softmax classification layer for our classes.
#
# Our loss function will be, as usual, categorical cross-entropy loss, and our learning algorithm will be [AdaDelta](https://arxiv.org/abs/1212.5701). Various things about this network can be changed to get better performance, perhaps using a larger network or a different optimizer will help, but for the purposes of this notebook, the goal is to just get an understanding of an approximate baseline for comparison's sake, and so it isn't neccessary to spend much time trying to optimize this network.
#
# Upon compiling the network, let's run `model.summary()` to get a snapshot of its layers.

# %%
# build the network
model = Sequential()
print("Input dimensions: ",x_train.shape[1:])

model.add(Conv2D(32, (3, 3), input_shape=x_train.shape[1:]))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(32, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Dropout(0.25))

model.add(Conv2D(32, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(32, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(256))
model.add(Activation('relu'))

model.add(Dropout(0.5))

model.add(Dense(num_classes))
model.add(Activation('softmax'))

model.summary()
# Out:
# Input dimensions:  (224, 224, 3)
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 222, 222, 32)      896
#
#  activation (Activation)     (None, 222, 222, 32)      0
#
#  max_pooling2d (MaxPooling2  (None, 111, 111, 32)      0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 109, 109, 32)      9248
#
#  activation_1 (Activation)   (None, 109, 109, 32)      0
#
#  max_pooling2d_1 (MaxPoolin  (None, 54, 54, 32)        0
#  g2D)
#
#  dropout (Dropout)           (None, 54, 54, 32)        0
#
#  conv2d_2 (Conv2D)           (None, 52, 52, 32)        9248
#
#  activation_2 (Activation)   (None, 52, 52, 32)        0
#
#  max_pooling2d_2 (MaxPoolin  (None, 26, 26, 32)        0
#  g2D)
#
#  conv2d_3 (Conv2D)           (None, 24, 24, 32)        9248
#
#  activation_3 (Activation)   (None, 24, 24, 32)        0
#
#  max_pooling2d_3 (MaxPoolin  (None, 12, 12, 32)        0
#  g2D)
#
#  dropout_1 (Dropout)         (None, 12, 12, 32)        0
#
#  flatten (Flatten)           (None, 4608)              0
#
#  dense (Dense)               (None, 256)               1179904
#
#  activation_4 (Activation)   (None, 256)               0
#
#  dropout_2 (Dropout)         (None, 256)               0
#
#  dense_1 (Dense)             (None, 17)                4369
#
#  activation_5 (Activation)   (None, 17)                0
#
# =================================================================
# Total params: 1212913 (4.63 MB)
# Trainable params: 1212913 (4.63 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# We've created a medium-sized network with ~1.2 million weights and biases (the parameters). Most of them are leading into the one pre-softmax fully-connected layer "dense_5".
#
# We can now go ahead and train our model for 100 epochs with a batch size of 128. We'll also record its history so we can plot the loss over time later.

# %%
# compile the model to use categorical cross-entropy loss function and adadelta optimizer
model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

history = model.fit(x_train, y_train,
                    batch_size=128,
                    epochs=10,
                    validation_data=(x_val, y_val),
                    verbose=0)
# Out:
# Epoch 1/10
# 10/10 [==============================] - 17s 736ms/step - loss: 2.8272 - accuracy: 0.0992 - val_loss: 2.8161 - val_accuracy: 0.1037
# Epoch 2/10
# 10/10 [==============================] - 3s 286ms/step - loss: 2.7483 - accuracy: 0.1246 - val_loss: 2.6989 - val_accuracy: 0.1519
# Epoch 3/10
# 10/10 [==============================] - 3s 294ms/step - loss: 2.5879 - accuracy: 0.1873 - val_loss: 2.5475 - val_accuracy: 0.1852
# Epoch 4/10
# 10/10 [==============================] - 3s 281ms/step - loss: 2.4652 - accuracy: 0.2373 - val_loss: 2.4598 - val_accuracy: 0.2556
# Epoch 5/10
# 10/10 [==============================] - 3s 266ms/step - loss: 2.2945 - accuracy: 0.2913 - val_loss: 2.2656 - val_accuracy: 0.2593
# Epoch 6/10
# 10/10 [==============================] - 3s 269ms/step - loss: 2.0837 - accuracy: 0.3317 - val_loss: 2.0719 - val_accuracy: 0.3852
# Epoch 7/10
# 10/10 [==============================] - 3s 297ms/step - loss: 1.8853 - accuracy: 0.4063 - val_loss: 1.8930 - val_accuracy: 0.4148
# Epoch 8/10
# 10/10 [==============================] - 3s 285ms/step - loss: 1.5995 - accuracy: 0.5095 - val_loss: 1.7657 - val_accuracy: 0.4667
# Epoch 9/10
# 10/10 [==============================] - 3s 270ms/step - loss: 1.4039 - accuracy: 0.5579 - val_loss: 1.6609 - val_accuracy: 0.4704
# Epoch 10/10
# 10/10 [==============================] - 3s 267ms/step - loss: 1.2178 - accuracy: 0.6127 - val_loss: 1.5259 - val_accuracy: 0.5185

# %% [markdown]
# Let's plot the validation loss and validation accuracy over time.

# %%
fig = plt.figure(figsize=(16,4))
ax = fig.add_subplot(121)
ax.plot(history.history["val_loss"])
ax.set_title("validation loss")
ax.set_xlabel("epochs")

ax2 = fig.add_subplot(122)
ax2.plot(history.history["val_accuracy"])
ax2.set_title("validation accuracy")
ax2.set_xlabel("epochs")
ax2.set_ylim(0, 1)

plt.show()

# %% [markdown]
# Notice that the validation loss begins to actually rise after around 16 epochs, even though validation accuracy remains roughly between 40% and 50%. This suggests our model begins overfitting around then, and best performance would have been achieved if we had stopped early around then. Nevertheless, our accuracy would not have likely been above 50%, and probably lower down.
#
# We can also get a final evaluation by running our model on the training set. Doing so, we get the following results:

# %%
loss, accuracy = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', loss)
print('Test accuracy:', accuracy)
# Out:
# Test loss: 1.483721137046814
# Test accuracy: 0.5814814567565918

# %% [markdown]
# Finally, we see that we have achieved a (top-1) accuracy of around 49%. That's not too bad for 6000 images, considering that if we were to use a naive strategy of taking random guesses, we would have only gotten around 1% accuracy.
#
# ## Transfer learning by starting with existing network
#
# Now we can move on to the main strategy for training an image classifier on our small dataset: by starting with a larger and already trained network.
#
# To start, we will load the VGG16 from keras, which was trained on ImageNet and the weights saved online. If this is your first time loading VGG16, you'll need to wait a bit for the weights to download from the web. Once the network is loaded, we can again inspect the layers with the `summary()` method.

# %%
vgg = keras.applications.VGG16(weights='imagenet', include_top=True)
vgg.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels.h5
# 553467096/553467096 [==============================] - 7s 0us/step
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  flatten (Flatten)           (None, 25088)             0
#
#  fc1 (Dense)                 (None, 4096)              102764544
#
#  fc2 (Dense)                 (None, 4096)              16781312
#
#  predictions (Dense)         (None, 1000)              4097000
#
# =================================================================
# Total params: 138357544 (527.79 MB)
# Trainable params: 138357544 (527.79 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# Notice that VGG16 is _much_ bigger than the network we constructed earlier. It contains 13 convolutional layers and two fully connected layers at the end, and has over 138 million parameters, around 100 times as many parameters than the network we made above. Like our first network, the majority of the parameters are stored in the connections leading into the first fully-connected layer.
#
# VGG16 was made to solve ImageNet, and achieves a [8.8% top-5 error rate](https://github.com/jcjohnson/cnn-benchmarks), which means that 91.2% of test samples were classified correctly within the top 5 predictions for each image. It's top-1 accuracy--equivalent to the accuracy metric we've been using (that the top prediction is correct)--is 73%. This is especially impressive since there are not just 97, but 1000 classes, meaning that random guesses would get us only 0.1% accuracy.
#
# In order to use this network for our task, we "remove" the final classification layer, the 1000-neuron softmax layer at the end, which corresponds to ImageNet, and instead replace it with a new softmax layer for our dataset, which contains 97 neurons in the case of the 101_ObjectCategories dataset.
#
# In terms of implementation, it's easier to simply create a copy of VGG from its input layer until the second to last layer, and then work with that, rather than modifying the VGG object directly. So technically we never "remove" anything, we just circumvent/ignore it. This can be done in the following way, by using the keras `Model` class to initialize a new model whose input layer is the same as VGG but whose output layer is our new softmax layer, called `new_classification_layer`. Note: although it appears we are duplicating this large network, internally Keras is actually just copying all the layers by reference, and thus we don't need to worry about overloading the memory.

# %%
# make a reference to VGG's input layer
inp = vgg.input

# make a new softmax layer with num_classes neurons
new_classification_layer = Dense(num_classes, activation='softmax')

# connect our new layer to the second to last layer in VGG, and make a reference to it
out = new_classification_layer(vgg.layers[-2].output)

# create a new network between inp and out
model_new = Model(inp, out)

# %% [markdown]
# We are going to retrain this network, `model_new` on the new dataset and labels. But first, we need to freeze the weights and biases in all the layers in the network, except our new one at the end, with the expectation that the features that were learned in VGG should still be fairly relevant to the new image classification task. Not optimal, but most likely better than what we can train to in our limited dataset.
#
# By setting the `trainable` flag in each layer false (except our new classification layer), we ensure all the weights and biases in those layers remain fixed, and we simply train the weights in the one layer at the end. In some cases, it is desirable to *not* freeze all the pre-classification layers. If your dataset has enough samples, and doesn't resemble ImageNet very much, it might be advantageous to fine-tune some of the VGG layers along with the new classifier, or possibly even all of them. To do this, you can change the below code to make more of the layers trainable.
#
# In the case of CalTech-101, we will just do feature extraction, fearing that fine-tuning too much with this dataset may overfit. But maybe we are wrong? A good exercise would be to try out both, and compare the results.
#
# So we go ahead and freeze the layers, and compile the new model with exactly the same optimizer and loss function as in our first network, for the sake of a fair comparison. We then run `summary` again to look at the network's architecture.

# %%
# make all layers untrainable by freezing weights (except for last layer)
for l, layer in enumerate(model_new.layers[:-1]):
    layer.trainable = False

# ensure the last layer is trainable/not frozen
for l, layer in enumerate(model_new.layers[-1:]):
    layer.trainable = True

model_new.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

model_new.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  flatten (Flatten)           (None, 25088)             0
#
#  fc1 (Dense)                 (None, 4096)              102764544
#
#  fc2 (Dense)                 (None, 4096)              16781312
#
#  dense_2 (Dense)             (None, 17)                69649
#
# =================================================================
# Total params: 134330193 (512.43 MB)
# Trainable params: 69649 (272.07 KB)
# Non-trainable params: 134260544 (512.16 MB)
# _________________________________________________________________

# %% [markdown]
# Looking at the summary, we see the network is identical to the VGG model we instantiated earlier, except the last layer, formerly a 1000-neuron softmax, has been replaced by a new 97-neuron softmax. Additionally, we still have roughly 134 million weights, but now the vast majority of them are "non-trainable params" because we froze the layers they are contained in. We now only have 397,000 trainable parameters, which is actually only a quarter of the number of parameters needed to train the first model.
#
# As before, we go ahead and train the new model, using the same hyperparameters (batch size and number of epochs) as before, along with the same optimization algorithm. We also keep track of its history as we go.

# %%
history2 = model_new.fit(x_train, y_train,
                         batch_size=128,
                         epochs=10,
                         validation_data=(x_val, y_val))
# Out:
# Epoch 1/10
# 10/10 [==============================] - 52s 3s/step - loss: 3.1547 - accuracy: 0.0762 - val_loss: 2.9349 - val_accuracy: 0.0519
# Epoch 2/10
# 10/10 [==============================] - 6s 662ms/step - loss: 2.8512 - accuracy: 0.1151 - val_loss: 2.7477 - val_accuracy: 0.1296
# Epoch 3/10
# 10/10 [==============================] - 6s 655ms/step - loss: 2.6028 - accuracy: 0.2000 - val_loss: 2.6201 - val_accuracy: 0.1926
# Epoch 4/10
# 10/10 [==============================] - 6s 662ms/step - loss: 2.4865 - accuracy: 0.2270 - val_loss: 2.5179 - val_accuracy: 0.1815
# Epoch 5/10
# 10/10 [==============================] - 6s 658ms/step - loss: 2.3643 - accuracy: 0.2635 - val_loss: 2.4028 - val_accuracy: 0.2926
# Epoch 6/10
# 10/10 [==============================] - 6s 655ms/step - loss: 2.2512 - accuracy: 0.3214 - val_loss: 2.3273 - val_accuracy: 0.3185
# Epoch 7/10
# 10/10 [==============================] - 6s 648ms/step - loss: 2.2073 - accuracy: 0.3325 - val_loss: 2.3337 - val_accuracy: 0.2444
# Epoch 8/10
# 10/10 [==============================] - 7s 671ms/step - loss: 2.1551 - accuracy: 0.3468 - val_loss: 2.3456 - val_accuracy: 0.2481
# Epoch 9/10
# 10/10 [==============================] - 6s 665ms/step - loss: 2.1050 - accuracy: 0.3556 - val_loss: 2.2487 - val_accuracy: 0.2778
# Epoch 10/10
# 10/10 [==============================] - 7s 676ms/step - loss: 2.0196 - accuracy: 0.4000 - val_loss: 2.2101 - val_accuracy: 0.3556

# %% [markdown]
# Our validation accuracy hovers close to 80% towards the end, which is more than 30% improvement on the original network trained from scratch (meaning that we make the wrong prediction on 20% of samples, rather than 50%).
#
# It's worth noting also that this network actually trains _slightly faster_ than the original network, despite having more than 100 times as many parameters! This is because freezing the weights negates the need to backpropagate through all those layers, saving us on runtime.
#
# Let's plot the validation loss and accuracy again, this time comparing the original model trained from scratch (in blue) and the new transfer-learned model in green.

# %%
fig = plt.figure(figsize=(16,4))
ax = fig.add_subplot(121)
ax.plot(history.history["val_loss"])
ax.plot(history2.history["val_loss"])
ax.set_title("validation loss")
ax.set_xlabel("epochs")

ax2 = fig.add_subplot(122)
ax2.plot(history.history["val_accuracy"])
ax2.plot(history2.history["val_accuracy"])
ax2.set_title("validation accuracy")
ax2.set_xlabel("epochs")
ax2.set_ylim(0, 1)

plt.show()

# %% [markdown]
# Notice that whereas the original model began overfitting around epoch 16, the new model continued to slowly decrease its loss over time, and likely would have improved its accuracy slightly with more iterations. The new model made it to roughly 80% top-1 accuracy (in the validation set) and continued to improve slowly through 100 epochs.
#
# It's possibly we could have improved the original model with better regularization or more dropout, but we surely would not have made up the >30% improvement in accuracy.
#
# Again, we do a final validation on the test set.

# %%
loss, accuracy = model_new.evaluate(x_test, y_test, verbose=0)

print('Test loss:', loss)
print('Test accuracy:', accuracy)
# Out:
# Test loss: 2.154240846633911
# Test accuracy: 0.34074074029922485

# %% [markdown]
# To predict a new image, simply run the following code to get the probabilities for each class.

# %%
img, x = get_image('celebrity/data/Sandra Bullock/091_37b0b664.jpg')
probabilities = model_new.predict([x])
# Out:
# 1/1 [==============================] - 0s 20ms/step

# %% [markdown]
# ### Improving the results
#
# 78.2% top-1 accuracy on 97 classes, roughly evenly distributed, is a pretty good achievement. It is not quite as impressive as the original VGG16 which achieved 73% top-1 accuracy on 1000 classes. Nevertheless, it is much better than what we were able to achieve with our original network, and there is room for improvement. Some techniques which possibly could have improved our performance.
#
# - Using data augementation: augmentation refers to using various modifications of the original training data, in the form of distortions, rotations, rescalings, lighting changes, etc to increase the size of the training set and create more tolerance for such distortions.
# - Using a different optimizer, adding more regularization/dropout, and other hyperparameters.
# - Training for longer (of course)
#
# A more advanced example of transfer learning in Keras, involving augmentation for a small 2-class dataset, can be found in the [Keras blog](https://blog.keras.io/building-powerful-image-classification-models-using-very-little-data.html).
